# %% [markdown]
# ## Dueling DQN
#
# ### principle：
# $Q(s,a|\theta ,\beta ,\alpha ) = V(s|\theta ,\beta ) + A(s,a|\theta ,\alpha )$
#
# ### actually：
# $Q(s,a|\theta ,\beta ,\alpha ) = V(s|\theta ,\beta ) + A(s,a|\theta ,\alpha ) - {1 \over {|A|}}\sum\limits_{a'} {A(s,a'|\theta ,\alpha )} $
#
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### discussion
#
# ### reference:
# https://www.cnblogs.com/xxxxxxxxx/p/12034554.html

# %%
import numpy as np
import torch
from torch import nn, optim
import os
import matplotlib.pyplot as plt
from atari_wrappers import make_atari, wrap_deepmind,LazyFrames

# %%
# preprocess
def prepro(obs):
    """
    preprocess observation 
    [84,84,4]=>[4,84,84]
    """
    obs = obs._force().transpose(2,0,1)/255  # 0-255 => 0-1, [84,84,4] => [4,84,84]
    return obs

# %%
# net
import torch
from torch import nn
class Net(nn.Module):
    """
    Initialize a deep Q-learning network as described in
    https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
    Arguments:
        in_channels: number of channel of input.
            i.e The number of most recent frames stacked together as describe in the paper
        out_num: number of action-value to output, one-to-one correspondence to action in game.
    """
    def __init__(self, in_channel=4, out_num=6):
        super(Net,self).__init__()
        # layer setting paramters
        layers = [32,64,64]
        # output_size = (input_size-kernel_size)/stride + 1
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channel,layers[0],kernel_size=8,stride=4), # [batch,4,84,84]=>[batch,layers[0],20,20] 
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(layers[0],layers[1],kernel_size=4,stride=2), # [batch,layers[0],20,20]=>[batch,layers[1],9,9]
            nn.ReLU(),
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(layers[1],layers[2],kernel_size=3,stride=1), # [batch,layers[1],9,9]=>[batch,layers[2],7,7]
            nn.ReLU(),
        )
        self.linear1 = nn.Sequential(
            nn.Linear(7*7*layers[2], 512),
            nn.ReLU()
        )
        self.linear_value = nn.Linear(256, 1)  # value
        self.linear_a = nn.Linear(256, out_num) # advantage
#         self.linear2 = nn.linear(512, out_num)  # for target
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # flatten
        x = x.reshape(x.size(0), -1)  # [batch, layers[2],7,7]=>[batch,layers[2]*7*7]
        x = self.linear1(x)  # [batch,-1]=>[batch,512]
        x_value = x[:,:256]  # half part for value fullconnect [batch,256]
        x_a = x[:,256:]      # half part for advantage fullconnect [batch,256]
        y_value = self.linear_value(x_value)
        y_a = self.linear_a(x_a)
        # y = F.softmax(y)  # turn to probability
        return y_value, y_a
pre_net = Net()
print(pre_net)
# Out:
# Net(
#   (conv1): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#   )
#   (linear1): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#   )
#   (linear_value): Linear(in_features=256, out_features=1, bias=True)
#   (linear_a): Linear(in_features=256, out_features=6, bias=True)
# )

# %%
class SumTree():
    data_point = 0  # data idx
    def __init__(self, capacity):
        self.capacity = capacity  # num of leaves
        self.tree = np.zeros(capacity*2-1)
        self.transition = np.zeros(capacity, dtype=object) # save data
        self.n_entries = 0
        
    def total_p(self):
        return self.tree[0]  # return the 0 node
        
    def add(self, p, data):
        # add data and priority
        # p: priority, data 
        idx = self.data_point + self.capacity -1
        self.transition[self.data_point] = data   # save data        
        self.data_point += 1
        if self.data_point >= self.capacity:
            self.data_point = 0            
        
        change = p - self.tree[idx]   
        self.tree[idx] = p            # save priority
        self.n_entries += 1   # count num of entries
        
        # propagation  update parents nodes
        p_idx = (idx-1)//2  # parent idx
        while True:           
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def update(self,idx, p):
        # update tree
        change = p - self.tree[idx]
        self.tree[idx] = p  # change priority in leaves node        
        # update parents node
        p_idx = (idx-1)//2   #
        while True:            
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def retrieve(self, p_idx, s):
        # search leaf idx for s        
        while True:
            l_idx = p_idx*2 + 1  # left child idx
            r_idx = l_idx +1     # right child idx  
            if l_idx >= self.capacity*2-1: # 其子节点超出，结点序号范围， 说明已经是叶子结点
                return p_idx 
            if self.tree[l_idx] >= s:
                p_idx = l_idx
            else:
                p_idx = r_idx
                s -= self.tree[l_idx]
            
    def get(self, s):
        # get a data and priority from tree and transition        
        # get idx of leaves
        idx = self.retrieve(0,s)
        priority = self.tree[idx]
        data_idx = idx - (self.capacity - 1)
        data = self.transition[data_idx]
        return idx, priority, data

# %%
# memory buffer replay
class Memory_buffer_replay():
    beta = 0.4
    beta_increment_per_sampling = 0.001
    abs_err_upper = 1.
    def __init__(self, capacity, device):
        self.capacity = capacity
        self.sumtree = SumTree(self.capacity)
        self.device = device
        
        self.e = 0.01
        self.a = 0.6
        self.prio_max = 0.1
        
    def store_record(self, state, state_next, a, r, done):
        data = (state, state_next, a, r, done)
        priority = (np.abs(self.prio_max) + self.e) ** self.a #  proportional priority
        self.sumtree.add(priority, data) # save p, data in sumtree
        
    def sample(self, batchsz):
        if self.sumtree.total_p()==0:
            return None
        states, state_nexts, a_s, r_s, done_s = [],[],[],[],[]
        idxs, ps, isweights = [],[],[]  # idss, prioritys
        segment = self.sumtree.total_p()/batchsz
        
        self.beta = np.min([1., self.beta+self.beta_increment_per_sampling])
        min_prob = np.min(self.sumtree.tree[-self.capacity:])/self.sumtree.total_p()
        
        for i in range(batchsz):
            down_bound = i*segment
            up_bound = (i+1)*segment
            s = np.random.uniform(down_bound, up_bound)
            idx, p, data = self.sumtree.get(s) 
            
            state, state_next, a, r, done = data
            prob = p/self.sumtree.total_p()
            isweight = np.power(prob/min_prob, -self.beta)
            
            isweights.append(isweight)
            idxs.append(idx)
            ps.append(p)
            states.append(state)
            state_nexts.append(state_next)
            a_s.append(a)
            r_s.append(r)
            done_s.append(done)
        
        #from list to numpy
#         idxs, ps = np.array(idxs), np.array(ps)
        # function: list=> tensor
        list2tensor = lambda data: torch.from_numpy(np.array(data)).to(self.device)
        
        isweights = list2tensor(isweights)
        states, state_nexts = list2tensor(states), list2tensor(state_nexts)
        a_s, r_s, done_s = list2tensor(a_s), list2tensor(r_s), list2tensor(done_s)
        # isweights: tensor, idx:list, ps:list, states:tensor, as, rs, done_s:tensor
        return isweights, idxs, ps, states, state_nexts, a_s, r_s, done_s
    
    def update(self, idxs, errors):
        # update data priority
        self.prio_max = max(self.prio_max, max(np.abs(errors)))
        for i, idx in enumerate(idxs):
            p = (np.abs(errors[i]) + self.e) ** self.a
            self.sumtree.update(idx, p)

# %%
# DQN with priority
import torch.nn.functional as F
class DQN_priority():
    def __init__(self, args, env, load_model=False):        
        # use cuda
        cuda = True
        if cuda:
            self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        else:
            self.device = torch.device('cpu')
            
        # env
        self.env = env
        self.n_actions = env.action_space.n
        self.dim_shape = env.observation_space.shape
        
        # hyperparams
        self.capacity = 100000
        self.decay = 0.99
        self.episodes = args.episodes
        self.log_interval = args.log_interval  # print state per log_interval epsisode
        self.save_interval = args.save_interval  # interval for save model 
        
        self.epilon_max = 1
        self.epilon_min = 0.01
        self.learning_start = 10000  # 装满10000 再开始
        self.epilon_decay = 30000
        
        # learn params
        self.lr = args.lr
        self.batchsz = args.batchsz
        self.iter =0
        self.iter_max = args.iter_max
        
        # build model
        self.eval_model = Net().to(self.device)
        self.tar_model = Net().to(self.device)  
        # load model
        if load_model:
            self.eval_model.load_state_dict(torch.load('dqn_priority.mdl'))
        self.tar_model.load_state_dict(self.eval_model.state_dict())
        # build optimizer
        self.optimizer = optim.RMSprop(self.eval_model.parameters(),lr=self.lr, eps=0.001, alpha=0.95)
#         self.optimizer = optim.Adam(self.eval_model.parameters(), self.lr)
#         self.cost_F = nn.MSELoss()
        
        # build memory buffer
        self.buffer = Memory_buffer_replay(self.capacity, self.device)
    
    def train(self):
        episodes = self.episodes
        losses = []
        rewards  = []
        
        # decay function explot ratio
        epilon_by_g_step = lambda step_idx:self.epilon_min + (self.epilon_max-self.epilon_min)*np.exp(-1*step_idx/self.epilon_decay)
        # global step
        global_step = 0
        
        for epis in range(episodes):
            state = self.env.reset()
            state = prepro(state) # [84,84,4]=>[4,84,84]
            reward_sum = 0
            loss_ = []
            # decay explot ratio
#             self.explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/50.)
            while True:
                # decay explot ratio
                epsilon = epilon_by_g_step(global_step)
                global_step += 1 
                act = self.make_action(state, epsilon) # choose action
                state_next, r, done, inf = self.env.step(act)
                state_next = prepro(state_next)
                reward_sum += r                
                # store data
                self.buffer.store_record(state, state_next, act, r, done)                
                if done:                    
                    rewards.append(reward_sum)
                    losses.append(np.mean(loss_))
                    break  # start another episode
                else:
                    state = state_next
            
                # learn model
                if self.buffer.sumtree.n_entries == self.learning_start:
                    print('#'*30 + 'start learning' + '#'*30)
                if self.buffer.sumtree.n_entries > self.learning_start:
                    loss = self.learn()
                    loss_.append(loss)
                else:
                    loss_.append(0)
                
            # print train state
            if epis%self.log_interval==0 and epis>0:
                #print(losses)
                print('global step:{}'.format(global_step-1),
                      'episode :{}/{}'.format(epis, self.episodes), 
                      'aver loss:{:.5f}'.format(np.mean(losses[-10:])), 
                      'aver reward:{:.5f}'.format(np.mean(rewards[-10:])),
                      'explot:{:.5f}'.format(epsilon)
                     )
            # save model
            if epis%self.save_interval==0 and epis>0:
                torch.save(self.eval_model.state_dict(),'dqn_priority.mdl')
        return losses, rewards
    
    def learn(self):
        # learn the model
        
        # get data,  idxs, ps : list. others tensor
        isweights, idxs, ps, state, state_next, act_s, r_s, done_s = self.buffer.sample(self.batchsz)        
        
        # pre
        eval_v,eval_a = self.eval_model(state.float())
        eval_v = eval_v.view(-1) # colum vector => row vector        
        eval_q = eval_v + eval_a.gather(1,act_s.unsqueeze(1).long()).squeeze(1) + eval_a.mean(1) #      
        eval_q = eval_q.squeeze(-1)  # [batch,1] => [batch]
        # compute label
        next_q_v, next_q_a = self.tar_model(state_next.float()) 
        next_q_v = next_q_v.view(-1)
        next_max_q = (next_q_v + next_q_a.max(1)[0] - next_q_a.mean(1)).detach() # torch.max() return [max_data, max_idx]
        next_max_q = next_max_q.squeeze(-1) 
        decay = torch.tensor(self.decay).float().to(self.device)
        tar_q = r_s.float() + decay*next_max_q
        tar_q = torch.where(done_s>0, r_s.float(), tar_q)  # Q_next = r when done is true
        
        #compute td-loss
        loss = F.smooth_l1_loss(eval_q, tar_q)
#         loss = torch.mean(isweights*torch.abs(eval_q - tar_q)) # loss expect input dim=[batch,1]
        # update buffer with error
        errors = (eval_q - tar_q).detach().cpu().tolist()
        self.buffer.update(idxs, errors)
        
        self.optimizer.zero_grad()
        loss.backward()
        # clip gradient
        for param in self.eval_model.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        
        # update tar_model
        self.iter += 1
        if self.iter%self.iter_max==0:
            self.tar_model.load_state_dict(self.eval_model.state_dict())
        
        return loss.cpu().item() # ruturn mean loss
    
    def make_action(self, state, epsilon=None):
        state = torch.from_numpy(state).float()
        
        pre_q_v, pre_q_a = self.eval_model(state.unsqueeze(0).to(self.device))
        pre_q_a = pre_q_a.cpu().detach()
        
        #explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/20.)
        if epsilon==None:
            epsilon=self.epsion_min
        if np.random.uniform()< epsilon:
            action = np.random.choice(self.n_actions) # random choose action
        else:
            action = torch.argmax(pre_q_a)
            action = action.item()
        return action

# %%
# argument
class Argument():
    def __init__(self):
        self.lr = 1e-3
        self.batchsz = 32
        
        self.episodes = 1000
        
        self.log_interval = 1 # print state per log_interval epsisode
        self.save_interval = 20  # interval for save model
        
        self.iter_max = 1000  # update tar_model interval

args = Argument()

# %%
# main
import gym
env = make_atari('PongNoFrameskip-v4') # only use in no frameskip environment
env = wrap_deepmind(env, scale = False, frame_stack=True )

load_model = False
run_dqn = DQN_priority(args, env, load_model)
losses, rewards = run_dqn.train()
# Out:
# global step:1918 episode :1/1000 aver loss:0.00000 aver reward:-19.50000 explot:0.93869
# global step:2808 episode :2/1000 aver loss:0.00000 aver reward:-19.66667 explot:0.91154
# global step:3899 episode :3/1000 aver loss:0.00000 aver reward:-19.25000 explot:0.87934
# global step:4659 episode :4/1000 aver loss:0.00000 aver reward:-19.60000 explot:0.85760
# global step:5415 episode :5/1000 aver loss:0.00000 aver reward:-19.83333 explot:0.83650
# global step:6411 episode :6/1000 aver loss:0.00000 aver reward:-19.71429 explot:0.80951
# global step:7172 episode :7/1000 aver loss:0.00000 aver reward:-19.87500 explot:0.78949
# global step:7930 episode :8/1000 aver loss:0.00000 aver reward:-20.00000 explot:0.77004
# global step:8690 episode :9/1000 aver loss:0.00000 aver reward:-20.10000 explot:0.75103
# global step:9508 episode :10/1000 aver loss:0.00000 aver reward:-20.40000 explot:0.73110
# ##############################start learning##############################
# /home/ryzen/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: divide by zero encountered in double_scalars
# global step:10420 episode :11/1000 aver loss:0.00137 aver reward:-20.30000 explot:0.70950
# global step:11419 episode :12/1000 aver loss:0.00498 aver reward:-20.20000 explot:0.68659
# global step:12235 episode :13/1000 aver loss:0.00697 aver reward:-20.50000 explot:0.66844
# global step:13199 episode :14/1000 aver loss:0.00835 aver reward:-20.40000 explot:0.64762
# global step:14201 episode :15/1000 aver loss:0.00912 aver reward:-20.20000 explot:0.62667
# global step:15136 episode :16/1000 aver loss:0.00959 aver reward:-20.40000 explot:0.60775
# global step:16387 episode :17/1000 aver loss:0.00997 aver reward:-20.10000 explot:0.58334
# global step:17145 episode :18/1000 aver loss:0.01024 aver reward:-20.10000 explot:0.56903
# global step:17990 episode :19/1000 aver loss:0.01044 aver reward:-20.10000 explot:0.55350
# global step:18748 episode :20/1000 aver loss:0.01065 aver reward:-20.10000 explot:0.53994
# global step:19703 episode :21/1000 aver loss:0.00941 aver reward:-20.10000 explot:0.52334
# global step:20620 episode :22/1000 aver loss:0.00592 aver reward:-20.20000 explot:0.50789
# global step:21501 episode :23/1000 aver loss:0.00403 aver reward:-20.20000 explot:0.49348
# global step:22438 episode :24/1000 aver loss:0.00276 aver reward:-20.10000 explot:0.47861
# global step:23313 episode :25/1000 aver loss:0.00208 aver reward:-20.30000 explot:0.46514
# global step:24073 episode :26/1000 aver loss:0.00169 aver reward:-20.30000 explot:0.45375
# global step:25017 episode :27/1000 aver loss:0.00139 aver reward:-20.50000 explot:0.44001
# global step:25950 episode :28/1000 aver loss:0.00120 aver reward:-20.30000 explot:0.42684
# global step:26843 episode :29/1000 aver loss:0.00107 aver reward:-20.20000 explot:0.41462
# global step:27704 episode :30/1000 aver loss:0.00095 aver reward:-20.10000 explot:0.40317
# global step:28466 episode :31/1000 aver loss:0.00088 aver reward:-20.20000 explot:0.39331
# global step:29361 episode :32/1000 aver loss:0.00083 aver reward:-20.20000 explot:0.38204
# global step:30135 episode :33/1000 aver loss:0.00081 aver reward:-20.20000 explot:0.37257
# global step:30920 episode :34/1000 aver loss:0.00079 aver reward:-20.40000 explot:0.36320
# global step:31831 episode :35/1000 aver loss:0.00077 aver reward:-20.40000 explot:0.35264
# global step:32741 episode :36/1000 aver loss:0.00076 aver reward:-20.30000 explot:0.34240
# global step:33683 episode :37/1000 aver loss:0.00074 aver reward:-20.40000 explot:0.33212
# global step:34580 episode :38/1000 aver loss:0.00073 aver reward:-20.50000 explot:0.32264
# global step:35339 episode :39/1000 aver loss:0.00070 aver reward:-20.60000 explot:0.31483
# global step:36210 episode :40/1000 aver loss:0.00067 aver reward:-20.60000 explot:0.30610
# global step:37131 episode :41/1000 aver loss:0.00065 aver reward:-20.50000 explot:0.29715
# global step:38201 episode :42/1000 aver loss:0.00062 aver reward:-20.30000 explot:0.28709
# global step:39140 episode :43/1000 aver loss:0.00057 aver reward:-20.30000 explot:0.27855
# global step:40093 episode :44/1000 aver loss:0.00053 aver reward:-20.20000 explot:0.27015
# global step:41137 episode :45/1000 aver loss:0.00050 aver reward:-20.00000 explot:0.26126
# global step:41955 episode :46/1000 aver loss:0.00047 aver reward:-20.10000 explot:0.25450
# global step:42949 episode :47/1000 aver loss:0.00044 aver reward:-19.90000 explot:0.24653
# global step:44086 episode :48/1000 aver loss:0.00041 aver reward:-19.80000 explot:0.23773
# global step:44921 episode :49/1000 aver loss:0.00040 aver reward:-19.80000 explot:0.23148
# global step:45798 episode :50/1000 aver loss:0.00039 aver reward:-19.90000 explot:0.22510
# global step:46638 episode :51/1000 aver loss:0.00037 aver reward:-20.00000 explot:0.21916
# global step:47690 episode :52/1000 aver loss:0.00037 aver reward:-20.10000 explot:0.21195
# global step:48739 episode :53/1000 aver loss:0.00038 aver reward:-19.90000 explot:0.20501
# global step:49578 episode :54/1000 aver loss:0.00037 aver reward:-20.00000 explot:0.19964
# global step:50617 episode :55/1000 aver loss:0.00037 aver reward:-20.10000 explot:0.19318
# global step:51480 episode :56/1000 aver loss:0.00036 aver reward:-20.10000 explot:0.18799
# global step:52387 episode :57/1000 aver loss:0.00036 aver reward:-20.30000 explot:0.18269
# global step:53372 episode :58/1000 aver loss:0.00036 aver reward:-20.50000 explot:0.17711
# global step:54471 episode :59/1000 aver loss:0.00036 aver reward:-20.20000 explot:0.17110
# global step:55310 episode :60/1000 aver loss:0.00036 aver reward:-20.20000 explot:0.16665
# global step:56332 episode :61/1000 aver loss:0.00036 aver reward:-20.00000 explot:0.16141
# global step:57233 episode :62/1000 aver loss:0.00036 aver reward:-20.10000 explot:0.15693
# global step:58367 episode :63/1000 aver loss:0.00034 aver reward:-20.20000 explot:0.15148
# global step:59214 episode :64/1000 aver loss:0.00033 aver reward:-20.20000 explot:0.14754
# global step:60215 episode :65/1000 aver loss:0.00032 aver reward:-20.30000 explot:0.14303
# global step:61117 episode :66/1000 aver loss:0.00031 aver reward:-20.20000 explot:0.13909
# global step:62421 episode :67/1000 aver loss:0.00031 aver reward:-19.90000 explot:0.13359
# global step:63587 episode :68/1000 aver loss:0.00031 aver reward:-19.70000 explot:0.12888
# global step:64609 episode :69/1000 aver loss:0.00031 aver reward:-19.80000 explot:0.12490
# global step:65580 episode :70/1000 aver loss:0.00031 aver reward:-19.80000 explot:0.12124
# global step:66584 episode :71/1000 aver loss:0.00031 aver reward:-19.80000 explot:0.11758
# global step:67670 episode :72/1000 aver loss:0.00031 aver reward:-19.90000 explot:0.11376
# global step:68852 episode :73/1000 aver loss:0.00032 aver reward:-19.70000 explot:0.10975
# global step:69737 episode :74/1000 aver loss:0.00032 aver reward:-19.60000 explot:0.10685
# global step:70732 episode :75/1000 aver loss:0.00033 aver reward:-19.50000 explot:0.10369
# global step:71861 episode :76/1000 aver loss:0.00033 aver reward:-19.50000 explot:0.10023
# global step:72886 episode :77/1000 aver loss:0.00033 aver reward:-19.80000 explot:0.09720
# global step:73731 episode :78/1000 aver loss:0.00032 aver reward:-20.00000 explot:0.09478
# global step:74666 episode :79/1000 aver loss:0.00031 aver reward:-20.20000 explot:0.09217
# global step:75641 episode :80/1000 aver loss:0.00030 aver reward:-20.10000 explot:0.08955
# global step:76693 episode :81/1000 aver loss:0.00030 aver reward:-20.10000 explot:0.08681
# global step:77684 episode :82/1000 aver loss:0.00029 aver reward:-19.90000 explot:0.08431
# global step:78758 episode :83/1000 aver loss:0.00029 aver reward:-20.10000 explot:0.08170
# global step:79919 episode :84/1000 aver loss:0.00028 aver reward:-19.90000 explot:0.07897
# global step:80843 episode :85/1000 aver loss:0.00028 aver reward:-19.90000 explot:0.07688
# global step:81978 episode :86/1000 aver loss:0.00027 aver reward:-19.80000 explot:0.07440
# global step:83152 episode :87/1000 aver loss:0.00027 aver reward:-19.60000 explot:0.07193
# global step:84285 episode :88/1000 aver loss:0.00027 aver reward:-19.50000 explot:0.06963
# global step:85275 episode :89/1000 aver loss:0.00027 aver reward:-19.40000 explot:0.06770
# global step:86451 episode :90/1000 aver loss:0.00027 aver reward:-19.30000 explot:0.06548
# global step:87482 episode :91/1000 aver loss:0.00028 aver reward:-19.40000 explot:0.06360
# global step:88869 episode :92/1000 aver loss:0.00028 aver reward:-19.00000 explot:0.06118
# global step:90006 episode :93/1000 aver loss:0.00027 aver reward:-18.80000 explot:0.05928
# global step:91226 episode :94/1000 aver loss:0.00027 aver reward:-18.90000 explot:0.05732
# global step:92303 episode :95/1000 aver loss:0.00028 aver reward:-19.00000 explot:0.05565
# global step:93567 episode :96/1000 aver loss:0.00027 aver reward:-18.70000 explot:0.05376
# global step:94696 episode :97/1000 aver loss:0.00027 aver reward:-18.60000 explot:0.05215
# global step:95947 episode :98/1000 aver loss:0.00027 aver reward:-18.60000 explot:0.05043
# global step:97169 episode :99/1000 aver loss:0.00027 aver reward:-18.40000 explot:0.04881
# global step:98308 episode :100/1000 aver loss:0.00027 aver reward:-18.40000 explot:0.04737
# global step:99361 episode :101/1000 aver loss:0.00027 aver reward:-18.30000 explot:0.04608
# global step:100499 episode :102/1000 aver loss:0.00027 aver reward:-18.80000 explot:0.04473
# global step:102193 episode :103/1000 aver loss:0.00028 aver reward:-18.50000 explot:0.04283
# global step:103287 episode :104/1000 aver loss:0.00029 aver reward:-18.40000 explot:0.04165
# global step:104376 episode :105/1000 aver loss:0.00029 aver reward:-18.30000 explot:0.04052
# global step:105416 episode :106/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.03948
# global step:106477 episode :107/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.03846
# global step:107757 episode :108/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.03727
# global step:109035 episode :109/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.03613
# global step:110223 episode :110/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.03512
# global step:111244 episode :111/1000 aver loss:0.00030 aver reward:-18.80000 explot:0.03428
# global step:112648 episode :112/1000 aver loss:0.00030 aver reward:-18.50000 explot:0.03317
# global step:113758 episode :113/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.03233
# global step:115367 episode :114/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.03116
# global step:116597 episode :115/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.03031
# global step:117551 episode :116/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.02967
# global step:118921 episode :117/1000 aver loss:0.00030 aver reward:-18.70000 explot:0.02880
# global step:120365 episode :118/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.02791
# global step:121586 episode :119/1000 aver loss:0.00030 aver reward:-18.60000 explot:0.02720
# global step:123194 episode :120/1000 aver loss:0.00030 aver reward:-18.50000 explot:0.02630
# global step:124544 episode :121/1000 aver loss:0.00030 aver reward:-17.90000 explot:0.02558
# global step:125809 episode :122/1000 aver loss:0.00030 aver reward:-18.00000 explot:0.02494
# global step:127058 episode :123/1000 aver loss:0.00030 aver reward:-18.20000 explot:0.02433
# global step:128283 episode :124/1000 aver loss:0.00029 aver reward:-18.40000 explot:0.02376
# global step:130104 episode :125/1000 aver loss:0.00030 aver reward:-18.00000 explot:0.02295
# global step:131515 episode :126/1000 aver loss:0.00029 aver reward:-17.70000 explot:0.02235
# global step:132633 episode :127/1000 aver loss:0.00029 aver reward:-17.90000 explot:0.02190
# global step:134315 episode :128/1000 aver loss:0.00030 aver reward:-17.70000 explot:0.02125
# global step:135542 episode :129/1000 aver loss:0.00030 aver reward:-17.70000 explot:0.02080
# global step:136828 episode :130/1000 aver loss:0.00030 aver reward:-17.90000 explot:0.02035
# global step:138554 episode :131/1000 aver loss:0.00031 aver reward:-17.90000 explot:0.01977
# global step:139799 episode :132/1000 aver loss:0.00031 aver reward:-18.10000 explot:0.01937
# global step:141281 episode :133/1000 aver loss:0.00032 aver reward:-17.70000 explot:0.01892
# global step:142712 episode :134/1000 aver loss:0.00033 aver reward:-17.40000 explot:0.01850
# global step:144315 episode :135/1000 aver loss:0.00035 aver reward:-17.40000 explot:0.01806
# global step:145877 episode :136/1000 aver loss:0.00036 aver reward:-17.30000 explot:0.01765
# global step:147005 episode :137/1000 aver loss:0.00038 aver reward:-17.00000 explot:0.01737
# global step:148415 episode :138/1000 aver loss:0.00039 aver reward:-17.30000 explot:0.01703
# global step:149847 episode :139/1000 aver loss:0.00040 aver reward:-17.20000 explot:0.01670
# global step:151544 episode :140/1000 aver loss:0.00039 aver reward:-16.80000 explot:0.01634
# global step:152968 episode :141/1000 aver loss:0.00039 aver reward:-16.90000 explot:0.01604
# global step:154706 episode :142/1000 aver loss:0.00038 aver reward:-16.30000 explot:0.01570
# global step:156394 episode :143/1000 aver loss:0.00038 aver reward:-16.30000 explot:0.01539
# global step:158092 episode :144/1000 aver loss:0.00038 aver reward:-16.10000 explot:0.01509
# global step:159865 episode :145/1000 aver loss:0.00037 aver reward:-16.10000 explot:0.01480
# global step:161175 episode :146/1000 aver loss:0.00036 aver reward:-16.20000 explot:0.01460
# global step:163034 episode :147/1000 aver loss:0.00035 aver reward:-15.80000 explot:0.01432
# global step:164540 episode :148/1000 aver loss:0.00034 aver reward:-15.70000 explot:0.01411
# global step:166330 episode :149/1000 aver loss:0.00035 aver reward:-15.40000 explot:0.01387
# global step:167327 episode :150/1000 aver loss:0.00036 aver reward:-15.90000 explot:0.01374
# global step:169232 episode :151/1000 aver loss:0.00036 aver reward:-15.60000 explot:0.01351
# global step:170761 episode :152/1000 aver loss:0.00036 aver reward:-15.90000 explot:0.01334
# global step:172429 episode :153/1000 aver loss:0.00036 aver reward:-16.00000 explot:0.01316
# global step:174297 episode :154/1000 aver loss:0.00035 aver reward:-16.20000 explot:0.01297
# global step:175711 episode :155/1000 aver loss:0.00036 aver reward:-16.50000 explot:0.01283
# global step:177370 episode :156/1000 aver loss:0.00036 aver reward:-16.30000 explot:0.01268
# global step:179056 episode :157/1000 aver loss:0.00036 aver reward:-16.50000 explot:0.01253
# global step:180750 episode :158/1000 aver loss:0.00037 aver reward:-16.40000 explot:0.01239
# global step:182412 episode :159/1000 aver loss:0.00037 aver reward:-16.50000 explot:0.01226
# global step:184219 episode :160/1000 aver loss:0.00037 aver reward:-16.00000 explot:0.01213
# global step:185528 episode :161/1000 aver loss:0.00038 aver reward:-16.60000 explot:0.01204
# global step:187013 episode :162/1000 aver loss:0.00038 aver reward:-16.90000 explot:0.01194
# global step:188970 episode :163/1000 aver loss:0.00038 aver reward:-16.50000 explot:0.01182
# global step:190625 episode :164/1000 aver loss:0.00038 aver reward:-16.10000 explot:0.01172
# global step:192508 episode :165/1000 aver loss:0.00038 aver reward:-16.00000 explot:0.01162
# global step:194172 episode :166/1000 aver loss:0.00039 aver reward:-16.30000 explot:0.01153
# global step:195817 episode :167/1000 aver loss:0.00038 aver reward:-16.20000 explot:0.01145
# global step:197569 episode :168/1000 aver loss:0.00037 aver reward:-16.00000 explot:0.01137
# global step:199424 episode :169/1000 aver loss:0.00037 aver reward:-16.10000 explot:0.01128
# global step:201153 episode :170/1000 aver loss:0.00037 aver reward:-16.10000 explot:0.01121
# global step:202703 episode :171/1000 aver loss:0.00036 aver reward:-15.80000 explot:0.01115
# global step:203862 episode :172/1000 aver loss:0.00036 aver reward:-15.70000 explot:0.01111
# global step:205583 episode :173/1000 aver loss:0.00037 aver reward:-16.30000 explot:0.01105
# global step:206984 episode :174/1000 aver loss:0.00038 aver reward:-16.70000 explot:0.01100
# global step:209104 episode :175/1000 aver loss:0.00038 aver reward:-16.60000 explot:0.01093
# global step:210813 episode :176/1000 aver loss:0.00038 aver reward:-16.20000 explot:0.01088
# global step:212558 episode :177/1000 aver loss:0.00039 aver reward:-16.30000 explot:0.01083
# global step:214047 episode :178/1000 aver loss:0.00039 aver reward:-16.60000 explot:0.01079
# global step:215298 episode :179/1000 aver loss:0.00038 aver reward:-16.70000 explot:0.01076
# global step:217144 episode :180/1000 aver loss:0.00038 aver reward:-16.60000 explot:0.01071
# global step:219218 episode :181/1000 aver loss:0.00038 aver reward:-16.50000 explot:0.01066
# global step:220783 episode :182/1000 aver loss:0.00038 aver reward:-16.30000 explot:0.01063
# global step:222512 episode :183/1000 aver loss:0.00037 aver reward:-16.10000 explot:0.01059
# global step:224345 episode :184/1000 aver loss:0.00036 aver reward:-16.00000 explot:0.01056
# global step:225828 episode :185/1000 aver loss:0.00036 aver reward:-16.30000 explot:0.01053
# global step:227471 episode :186/1000 aver loss:0.00035 aver reward:-16.60000 explot:0.01050
# global step:229297 episode :187/1000 aver loss:0.00035 aver reward:-16.70000 explot:0.01047
# global step:231074 episode :188/1000 aver loss:0.00035 aver reward:-16.50000 explot:0.01045
# global step:233354 episode :189/1000 aver loss:0.00034 aver reward:-15.90000 explot:0.01041
# global step:235709 episode :190/1000 aver loss:0.00034 aver reward:-15.80000 explot:0.01038
# global step:237337 episode :191/1000 aver loss:0.00034 aver reward:-16.10000 explot:0.01036
# global step:239515 episode :192/1000 aver loss:0.00034 aver reward:-15.90000 explot:0.01034
# global step:241353 episode :193/1000 aver loss:0.00034 aver reward:-15.90000 explot:0.01032
# global step:243235 episode :194/1000 aver loss:0.00033 aver reward:-15.70000 explot:0.01030
# global step:245256 episode :195/1000 aver loss:0.00032 aver reward:-15.00000 explot:0.01028
# global step:247383 episode :196/1000 aver loss:0.00032 aver reward:-14.50000 explot:0.01026
# global step:249333 episode :197/1000 aver loss:0.00031 aver reward:-14.30000 explot:0.01024
# global step:251387 episode :198/1000 aver loss:0.00030 aver reward:-14.10000 explot:0.01023
# global step:253011 episode :199/1000 aver loss:0.00030 aver reward:-14.60000 explot:0.01022
# global step:255134 episode :200/1000 aver loss:0.00030 aver reward:-14.40000 explot:0.01020
# global step:257122 episode :201/1000 aver loss:0.00029 aver reward:-13.90000 explot:0.01019
# global step:259135 episode :202/1000 aver loss:0.00029 aver reward:-13.90000 explot:0.01018
# global step:261405 episode :203/1000 aver loss:0.00029 aver reward:-13.50000 explot:0.01016
# global step:262682 episode :204/1000 aver loss:0.00028 aver reward:-14.00000 explot:0.01016
# global step:264256 episode :205/1000 aver loss:0.00028 aver reward:-14.50000 explot:0.01015
# global step:266349 episode :206/1000 aver loss:0.00028 aver reward:-14.80000 explot:0.01014
# global step:268532 episode :207/1000 aver loss:0.00027 aver reward:-14.20000 explot:0.01013
# global step:270753 episode :208/1000 aver loss:0.00027 aver reward:-13.80000 explot:0.01012
# global step:272520 episode :209/1000 aver loss:0.00027 aver reward:-13.50000 explot:0.01011
# global step:274289 episode :210/1000 aver loss:0.00027 aver reward:-13.70000 explot:0.01011
# global step:276580 episode :211/1000 aver loss:0.00027 aver reward:-13.70000 explot:0.01010
# global step:278701 episode :212/1000 aver loss:0.00028 aver reward:-13.60000 explot:0.01009
# global step:281260 episode :213/1000 aver loss:0.00028 aver reward:-13.10000 explot:0.01008
# global step:283706 episode :214/1000 aver loss:0.00028 aver reward:-12.00000 explot:0.01008
# global step:285881 episode :215/1000 aver loss:0.00029 aver reward:-11.40000 explot:0.01007
# global step:287858 episode :216/1000 aver loss:0.00029 aver reward:-11.50000 explot:0.01007
# global step:289878 episode :217/1000 aver loss:0.00030 aver reward:-11.90000 explot:0.01006
# global step:292110 episode :218/1000 aver loss:0.00030 aver reward:-11.90000 explot:0.01006
# global step:293932 episode :219/1000 aver loss:0.00030 aver reward:-12.20000 explot:0.01006
# global step:296070 episode :220/1000 aver loss:0.00030 aver reward:-12.10000 explot:0.01005
# global step:298046 episode :221/1000 aver loss:0.00030 aver reward:-12.30000 explot:0.01005
# global step:300097 episode :222/1000 aver loss:0.00030 aver reward:-12.10000 explot:0.01004
# global step:302152 episode :223/1000 aver loss:0.00030 aver reward:-13.00000 explot:0.01004
# global step:304504 episode :224/1000 aver loss:0.00030 aver reward:-13.20000 explot:0.01004
# global step:306724 episode :225/1000 aver loss:0.00029 aver reward:-13.30000 explot:0.01004
# global step:308825 episode :226/1000 aver loss:0.00029 aver reward:-12.80000 explot:0.01003
# global step:311038 episode :227/1000 aver loss:0.00029 aver reward:-12.80000 explot:0.01003
# global step:312739 episode :228/1000 aver loss:0.00029 aver reward:-13.50000 explot:0.01003
# global step:314677 episode :229/1000 aver loss:0.00029 aver reward:-13.30000 explot:0.01003
# global step:316733 episode :230/1000 aver loss:0.00028 aver reward:-13.60000 explot:0.01003
# global step:319429 episode :231/1000 aver loss:0.00028 aver reward:-12.70000 explot:0.01002
# global step:321370 episode :232/1000 aver loss:0.00028 aver reward:-12.60000 explot:0.01002
# global step:323523 episode :233/1000 aver loss:0.00027 aver reward:-12.20000 explot:0.01002
# global step:325984 episode :234/1000 aver loss:0.00027 aver reward:-12.10000 explot:0.01002
# global step:327715 episode :235/1000 aver loss:0.00026 aver reward:-12.40000 explot:0.01002
# global step:329772 episode :236/1000 aver loss:0.00026 aver reward:-12.50000 explot:0.01002
# global step:332350 episode :237/1000 aver loss:0.00025 aver reward:-12.00000 explot:0.01002
# global step:334987 episode :238/1000 aver loss:0.00025 aver reward:-11.30000 explot:0.01001
# global step:337258 episode :239/1000 aver loss:0.00025 aver reward:-10.60000 explot:0.01001
# global step:339611 episode :240/1000 aver loss:0.00024 aver reward:-10.10000 explot:0.01001
# global step:341601 episode :241/1000 aver loss:0.00024 aver reward:-11.00000 explot:0.01001
# global step:343537 episode :242/1000 aver loss:0.00024 aver reward:-11.40000 explot:0.01001
# global step:345579 episode :243/1000 aver loss:0.00024 aver reward:-11.70000 explot:0.01001
# global step:348332 episode :244/1000 aver loss:0.00023 aver reward:-11.30000 explot:0.01001
# global step:350315 episode :245/1000 aver loss:0.00024 aver reward:-11.40000 explot:0.01001
# global step:352496 episode :246/1000 aver loss:0.00025 aver reward:-11.20000 explot:0.01001
# global step:354678 episode :247/1000 aver loss:0.00025 aver reward:-11.70000 explot:0.01001
# global step:356964 episode :248/1000 aver loss:0.00026 aver reward:-11.90000 explot:0.01001
# global step:358903 episode :249/1000 aver loss:0.00027 aver reward:-12.50000 explot:0.01001
# global step:361009 episode :250/1000 aver loss:0.00027 aver reward:-12.80000 explot:0.01001
# global step:363626 episode :251/1000 aver loss:0.00027 aver reward:-12.20000 explot:0.01001
# global step:365204 episode :252/1000 aver loss:0.00027 aver reward:-12.30000 explot:0.01001
# global step:367230 episode :253/1000 aver loss:0.00027 aver reward:-12.20000 explot:0.01000
# global step:369671 episode :254/1000 aver loss:0.00027 aver reward:-12.50000 explot:0.01000
# global step:372044 episode :255/1000 aver loss:0.00027 aver reward:-11.90000 explot:0.01000
# global step:373730 episode :256/1000 aver loss:0.00026 aver reward:-12.70000 explot:0.01000
# global step:375823 episode :257/1000 aver loss:0.00025 aver reward:-12.60000 explot:0.01000
# global step:378425 episode :258/1000 aver loss:0.00024 aver reward:-12.60000 explot:0.01000
# global step:380960 episode :259/1000 aver loss:0.00023 aver reward:-12.10000 explot:0.01000
# global step:383223 episode :260/1000 aver loss:0.00023 aver reward:-12.10000 explot:0.01000
# global step:385499 episode :261/1000 aver loss:0.00023 aver reward:-12.60000 explot:0.01000
# global step:387602 episode :262/1000 aver loss:0.00023 aver reward:-12.10000 explot:0.01000
# global step:389391 episode :263/1000 aver loss:0.00022 aver reward:-12.40000 explot:0.01000
# global step:391211 episode :264/1000 aver loss:0.00022 aver reward:-13.20000 explot:0.01000
# global step:393570 episode :265/1000 aver loss:0.00022 aver reward:-13.50000 explot:0.01000
# global step:395791 episode :266/1000 aver loss:0.00022 aver reward:-12.80000 explot:0.01000
# global step:397892 episode :267/1000 aver loss:0.00022 aver reward:-12.60000 explot:0.01000
# global step:400049 episode :268/1000 aver loss:0.00021 aver reward:-12.80000 explot:0.01000
# global step:402360 episode :269/1000 aver loss:0.00021 aver reward:-13.00000 explot:0.01000
# global step:404158 episode :270/1000 aver loss:0.00020 aver reward:-13.40000 explot:0.01000
# global step:406827 episode :271/1000 aver loss:0.00020 aver reward:-12.90000 explot:0.01000
# global step:409052 episode :272/1000 aver loss:0.00020 aver reward:-13.00000 explot:0.01000
# global step:411755 episode :273/1000 aver loss:0.00020 aver reward:-12.30000 explot:0.01000
# global step:413995 episode :274/1000 aver loss:0.00020 aver reward:-12.00000 explot:0.01000
# global step:416660 episode :275/1000 aver loss:0.00019 aver reward:-11.60000 explot:0.01000
# global step:419185 episode :276/1000 aver loss:0.00019 aver reward:-11.20000 explot:0.01000
# global step:421580 episode :277/1000 aver loss:0.00019 aver reward:-11.20000 explot:0.01000
# global step:423926 episode :278/1000 aver loss:0.00018 aver reward:-11.00000 explot:0.01000
# global step:426510 episode :279/1000 aver loss:0.00018 aver reward:-10.80000 explot:0.01000
# global step:429055 episode :280/1000 aver loss:0.00018 aver reward:-9.80000 explot:0.01000
# global step:431692 episode :281/1000 aver loss:0.00018 aver reward:-10.20000 explot:0.01000
# global step:433927 episode :282/1000 aver loss:0.00018 aver reward:-10.30000 explot:0.01000
# global step:436555 episode :283/1000 aver loss:0.00018 aver reward:-10.40000 explot:0.01000
# global step:439049 episode :284/1000 aver loss:0.00018 aver reward:-10.10000 explot:0.01000
# global step:441689 episode :285/1000 aver loss:0.00018 aver reward:-10.20000 explot:0.01000
# global step:444045 episode :286/1000 aver loss:0.00019 aver reward:-10.60000 explot:0.01000
# global step:445995 episode :287/1000 aver loss:0.00019 aver reward:-11.10000 explot:0.01000
# global step:448413 episode :288/1000 aver loss:0.00019 aver reward:-10.50000 explot:0.01000
# global step:450670 episode :289/1000 aver loss:0.00019 aver reward:-11.10000 explot:0.01000
# global step:453289 episode :290/1000 aver loss:0.00019 aver reward:-11.60000 explot:0.01000
# global step:456289 episode :291/1000 aver loss:0.00020 aver reward:-10.60000 explot:0.01000
# global step:458825 episode :292/1000 aver loss:0.00020 aver reward:-10.20000 explot:0.01000
# global step:461847 episode :293/1000 aver loss:0.00020 aver reward:-9.50000 explot:0.01000
# global step:465002 episode :294/1000 aver loss:0.00020 aver reward:-8.80000 explot:0.01000
# global step:467349 episode :295/1000 aver loss:0.00020 aver reward:-8.90000 explot:0.01000
# global step:470553 episode :296/1000 aver loss:0.00020 aver reward:-8.00000 explot:0.01000
# global step:473663 episode :297/1000 aver loss:0.00020 aver reward:-7.20000 explot:0.01000
# global step:476493 episode :298/1000 aver loss:0.00020 aver reward:-7.30000 explot:0.01000
# global step:479335 episode :299/1000 aver loss:0.00019 aver reward:-6.60000 explot:0.01000
# global step:482176 episode :300/1000 aver loss:0.00019 aver reward:-5.90000 explot:0.01000
# global step:485164 episode :301/1000 aver loss:0.00019 aver reward:-6.30000 explot:0.01000
# global step:487273 episode :302/1000 aver loss:0.00019 aver reward:-6.70000 explot:0.01000
# global step:490451 episode :303/1000 aver loss:0.00019 aver reward:-7.00000 explot:0.01000
# global step:492846 episode :304/1000 aver loss:0.00018 aver reward:-7.70000 explot:0.01000
# global step:494988 episode :305/1000 aver loss:0.00018 aver reward:-7.70000 explot:0.01000
# global step:497321 episode :306/1000 aver loss:0.00018 aver reward:-8.70000 explot:0.01000
# global step:499592 episode :307/1000 aver loss:0.00018 aver reward:-9.40000 explot:0.01000
# global step:502429 episode :308/1000 aver loss:0.00018 aver reward:-9.60000 explot:0.01000
# global step:504830 episode :309/1000 aver loss:0.00018 aver reward:-9.90000 explot:0.01000
# global step:506792 episode :310/1000 aver loss:0.00019 aver reward:-11.00000 explot:0.01000
# global step:509575 episode :311/1000 aver loss:0.00018 aver reward:-10.80000 explot:0.01000
# global step:511496 episode :312/1000 aver loss:0.00018 aver reward:-11.40000 explot:0.01000
# global step:513594 episode :313/1000 aver loss:0.00018 aver reward:-12.20000 explot:0.01000
# global step:515737 episode :314/1000 aver loss:0.00018 aver reward:-12.60000 explot:0.01000
# global step:517871 episode :315/1000 aver loss:0.00018 aver reward:-12.90000 explot:0.01000
# global step:520358 episode :316/1000 aver loss:0.00018 aver reward:-13.10000 explot:0.01000
# global step:522238 episode :317/1000 aver loss:0.00018 aver reward:-13.20000 explot:0.01000
# global step:524758 episode :318/1000 aver loss:0.00018 aver reward:-13.50000 explot:0.01000
# global step:527644 episode :319/1000 aver loss:0.00017 aver reward:-13.30000 explot:0.01000
# global step:529846 episode :320/1000 aver loss:0.00017 aver reward:-12.90000 explot:0.01000
# global step:532923 episode :321/1000 aver loss:0.00017 aver reward:-12.90000 explot:0.01000
# global step:535104 episode :322/1000 aver loss:0.00017 aver reward:-12.60000 explot:0.01000
# global step:537291 episode :323/1000 aver loss:0.00018 aver reward:-12.60000 explot:0.01000
# global step:539316 episode :324/1000 aver loss:0.00018 aver reward:-12.70000 explot:0.01000
# global step:541386 episode :325/1000 aver loss:0.00018 aver reward:-12.80000 explot:0.01000
# global step:543018 episode :326/1000 aver loss:0.00018 aver reward:-13.10000 explot:0.01000
# global step:545343 episode :327/1000 aver loss:0.00018 aver reward:-12.60000 explot:0.01000
# global step:547153 episode :328/1000 aver loss:0.00018 aver reward:-12.90000 explot:0.01000
# global step:549992 episode :329/1000 aver loss:0.00018 aver reward:-12.60000 explot:0.01000
# global step:552642 episode :330/1000 aver loss:0.00018 aver reward:-12.40000 explot:0.01000
# global step:554624 episode :331/1000 aver loss:0.00018 aver reward:-13.30000 explot:0.01000
# global step:557412 episode :332/1000 aver loss:0.00018 aver reward:-12.70000 explot:0.01000
# global step:559892 episode :333/1000 aver loss:0.00018 aver reward:-12.30000 explot:0.01000
# global step:562792 episode :334/1000 aver loss:0.00018 aver reward:-11.60000 explot:0.01000
# global step:564552 episode :335/1000 aver loss:0.00018 aver reward:-11.80000 explot:0.01000
# global step:566347 episode :336/1000 aver loss:0.00019 aver reward:-11.80000 explot:0.01000
# global step:568277 episode :337/1000 aver loss:0.00019 aver reward:-12.40000 explot:0.01000
# global step:570288 episode :338/1000 aver loss:0.00019 aver reward:-12.40000 explot:0.01000
# global step:573114 episode :339/1000 aver loss:0.00019 aver reward:-12.00000 explot:0.01000
# global step:576076 episode :340/1000 aver loss:0.00019 aver reward:-11.50000 explot:0.01000
# global step:578309 episode :341/1000 aver loss:0.00019 aver reward:-11.30000 explot:0.01000
# global step:580607 episode :342/1000 aver loss:0.00019 aver reward:-11.50000 explot:0.01000
# global step:583559 episode :343/1000 aver loss:0.00019 aver reward:-10.90000 explot:0.01000
# global step:585757 episode :344/1000 aver loss:0.00019 aver reward:-11.20000 explot:0.01000
# global step:588822 episode :345/1000 aver loss:0.00019 aver reward:-10.20000 explot:0.01000
# global step:591104 episode :346/1000 aver loss:0.00019 aver reward:-9.70000 explot:0.01000
# global step:593279 episode :347/1000 aver loss:0.00019 aver reward:-9.70000 explot:0.01000
# global step:595887 episode :348/1000 aver loss:0.00019 aver reward:-9.10000 explot:0.01000
# global step:597765 episode :349/1000 aver loss:0.00019 aver reward:-10.40000 explot:0.01000
# global step:599834 episode :350/1000 aver loss:0.00020 aver reward:-11.20000 explot:0.01000
# global step:602360 episode :351/1000 aver loss:0.00020 aver reward:-11.00000 explot:0.01000
# global step:604661 episode :352/1000 aver loss:0.00020 aver reward:-10.80000 explot:0.01000
# global step:606959 episode :353/1000 aver loss:0.00021 aver reward:-11.60000 explot:0.01000
# global step:609647 episode :354/1000 aver loss:0.00021 aver reward:-11.30000 explot:0.01000
# global step:611675 episode :355/1000 aver loss:0.00022 aver reward:-11.80000 explot:0.01000
# global step:613442 episode :356/1000 aver loss:0.00022 aver reward:-12.10000 explot:0.01000
# global step:615446 episode :357/1000 aver loss:0.00022 aver reward:-12.10000 explot:0.01000
# global step:617814 episode :358/1000 aver loss:0.00022 aver reward:-12.60000 explot:0.01000
# global step:619998 episode :359/1000 aver loss:0.00022 aver reward:-12.30000 explot:0.01000
# global step:622227 episode :360/1000 aver loss:0.00022 aver reward:-12.30000 explot:0.01000
# global step:623879 episode :361/1000 aver loss:0.00022 aver reward:-13.20000 explot:0.01000
# global step:626089 episode :362/1000 aver loss:0.00022 aver reward:-13.50000 explot:0.01000
# global step:627994 episode :363/1000 aver loss:0.00022 aver reward:-14.20000 explot:0.01000
# global step:630085 episode :364/1000 aver loss:0.00022 aver reward:-15.00000 explot:0.01000
# global step:632406 episode :365/1000 aver loss:0.00022 aver reward:-15.00000 explot:0.01000
# global step:634954 episode :366/1000 aver loss:0.00023 aver reward:-14.30000 explot:0.01000
# global step:637524 episode :367/1000 aver loss:0.00023 aver reward:-13.90000 explot:0.01000
# global step:640113 episode :368/1000 aver loss:0.00023 aver reward:-13.40000 explot:0.01000
# global step:642326 episode :369/1000 aver loss:0.00023 aver reward:-14.00000 explot:0.01000
# global step:644722 episode :370/1000 aver loss:0.00023 aver reward:-13.90000 explot:0.01000
# global step:647354 episode :371/1000 aver loss:0.00023 aver reward:-13.00000 explot:0.01000
# global step:649905 episode :372/1000 aver loss:0.00023 aver reward:-13.10000 explot:0.01000
# global step:653139 episode :373/1000 aver loss:0.00023 aver reward:-11.70000 explot:0.01000
# global step:656223 episode :374/1000 aver loss:0.00023 aver reward:-10.80000 explot:0.01000
# global step:658618 episode :375/1000 aver loss:0.00022 aver reward:-10.80000 explot:0.01000
# global step:660030 episode :376/1000 aver loss:0.00022 aver reward:-12.00000 explot:0.01000
# global step:662082 episode :377/1000 aver loss:0.00022 aver reward:-12.20000 explot:0.01000
# global step:664851 episode :378/1000 aver loss:0.00021 aver reward:-11.90000 explot:0.01000
# global step:666474 episode :379/1000 aver loss:0.00021 aver reward:-11.90000 explot:0.01000
# global step:669427 episode :380/1000 aver loss:0.00021 aver reward:-11.10000 explot:0.01000
# global step:671958 episode :381/1000 aver loss:0.00021 aver reward:-11.10000 explot:0.01000
# global step:673597 episode :382/1000 aver loss:0.00021 aver reward:-11.60000 explot:0.01000
# global step:675580 episode :383/1000 aver loss:0.00021 aver reward:-12.40000 explot:0.01000
# global step:677151 episode :384/1000 aver loss:0.00021 aver reward:-13.80000 explot:0.01000
# global step:679710 episode :385/1000 aver loss:0.00021 aver reward:-13.50000 explot:0.01000
# global step:681585 episode :386/1000 aver loss:0.00021 aver reward:-13.00000 explot:0.01000
# global step:684147 episode :387/1000 aver loss:0.00021 aver reward:-12.50000 explot:0.01000
# global step:687118 episode :388/1000 aver loss:0.00021 aver reward:-12.60000 explot:0.01000
# global step:688756 episode :389/1000 aver loss:0.00021 aver reward:-12.50000 explot:0.01000
# global step:691495 episode :390/1000 aver loss:0.00021 aver reward:-12.80000 explot:0.01000
# global step:693833 episode :391/1000 aver loss:0.00021 aver reward:-12.80000 explot:0.01000
# global step:696530 episode :392/1000 aver loss:0.00021 aver reward:-12.10000 explot:0.01000
# global step:699391 episode :393/1000 aver loss:0.00022 aver reward:-11.90000 explot:0.01000
# global step:702494 episode :394/1000 aver loss:0.00022 aver reward:-10.50000 explot:0.01000
# global step:704811 episode :395/1000 aver loss:0.00023 aver reward:-11.10000 explot:0.01000
# global step:706944 episode :396/1000 aver loss:0.00023 aver reward:-11.20000 explot:0.01000
# global step:708796 episode :397/1000 aver loss:0.00023 aver reward:-11.50000 explot:0.01000
# global step:711491 episode :398/1000 aver loss:0.00024 aver reward:-12.00000 explot:0.01000
# global step:714210 episode :399/1000 aver loss:0.00024 aver reward:-11.30000 explot:0.01000
# global step:716115 episode :400/1000 aver loss:0.00024 aver reward:-12.10000 explot:0.01000
# global step:718748 episode :401/1000 aver loss:0.00025 aver reward:-12.40000 explot:0.01000
# global step:720958 episode :402/1000 aver loss:0.00025 aver reward:-12.40000 explot:0.01000
# global step:723487 episode :403/1000 aver loss:0.00025 aver reward:-12.20000 explot:0.01000
# global step:725279 episode :404/1000 aver loss:0.00024 aver reward:-13.10000 explot:0.01000
# global step:727853 episode :405/1000 aver loss:0.00024 aver reward:-12.70000 explot:0.01000
# global step:730127 episode :406/1000 aver loss:0.00023 aver reward:-12.00000 explot:0.01000
# global step:732618 episode :407/1000 aver loss:0.00023 aver reward:-11.70000 explot:0.01000
# global step:734698 episode :408/1000 aver loss:0.00023 aver reward:-11.90000 explot:0.01000
# global step:736844 episode :409/1000 aver loss:0.00022 aver reward:-12.20000 explot:0.01000
# global step:739522 episode :410/1000 aver loss:0.00022 aver reward:-11.70000 explot:0.01000
# global step:741951 episode :411/1000 aver loss:0.00022 aver reward:-11.50000 explot:0.01000
# global step:744433 episode :412/1000 aver loss:0.00022 aver reward:-11.60000 explot:0.01000
# global step:746963 episode :413/1000 aver loss:0.00023 aver reward:-11.50000 explot:0.01000
# global step:749071 episode :414/1000 aver loss:0.00023 aver reward:-11.20000 explot:0.01000
# global step:751862 episode :415/1000 aver loss:0.00024 aver reward:-10.80000 explot:0.01000
# global step:754303 episode :416/1000 aver loss:0.00024 aver reward:-10.70000 explot:0.01000
# global step:756442 episode :417/1000 aver loss:0.00024 aver reward:-10.90000 explot:0.01000
# global step:758802 episode :418/1000 aver loss:0.00024 aver reward:-10.80000 explot:0.01000
# global step:761507 episode :419/1000 aver loss:0.00025 aver reward:-10.00000 explot:0.01000
# global step:763678 episode :420/1000 aver loss:0.00025 aver reward:-10.40000 explot:0.01000
# global step:765766 episode :421/1000 aver loss:0.00025 aver reward:-10.60000 explot:0.01000
# global step:767668 episode :422/1000 aver loss:0.00025 aver reward:-11.00000 explot:0.01000
# global step:770355 episode :423/1000 aver loss:0.00025 aver reward:-11.10000 explot:0.01000
# global step:772830 episode :424/1000 aver loss:0.00025 aver reward:-10.70000 explot:0.01000
# global step:774699 episode :425/1000 aver loss:0.00025 aver reward:-11.70000 explot:0.01000
# global step:776970 episode :426/1000 aver loss:0.00025 aver reward:-12.40000 explot:0.01000
# global step:779056 episode :427/1000 aver loss:0.00026 aver reward:-13.00000 explot:0.01000
# global step:781639 episode :428/1000 aver loss:0.00026 aver reward:-13.00000 explot:0.01000
# global step:784343 episode :429/1000 aver loss:0.00027 aver reward:-13.70000 explot:0.01000
# global step:786502 episode :430/1000 aver loss:0.00028 aver reward:-13.70000 explot:0.01000
# global step:788937 episode :431/1000 aver loss:0.00028 aver reward:-13.60000 explot:0.01000
# global step:791668 episode :432/1000 aver loss:0.00029 aver reward:-12.60000 explot:0.01000
# global step:793993 episode :433/1000 aver loss:0.00029 aver reward:-13.00000 explot:0.01000
# global step:796704 episode :434/1000 aver loss:0.00030 aver reward:-13.10000 explot:0.01000
# global step:799278 episode :435/1000 aver loss:0.00030 aver reward:-12.50000 explot:0.01000
# global step:801677 episode :436/1000 aver loss:0.00030 aver reward:-12.20000 explot:0.01000
# global step:803278 episode :437/1000 aver loss:0.00029 aver reward:-12.40000 explot:0.01000
# global step:805645 episode :438/1000 aver loss:0.00029 aver reward:-12.00000 explot:0.01000
# global step:807610 episode :439/1000 aver loss:0.00029 aver reward:-12.30000 explot:0.01000
# global step:809695 episode :440/1000 aver loss:0.00028 aver reward:-12.40000 explot:0.01000
# global step:812663 episode :441/1000 aver loss:0.00028 aver reward:-11.70000 explot:0.01000
# global step:814548 episode :442/1000 aver loss:0.00027 aver reward:-12.70000 explot:0.01000
# global step:817413 episode :443/1000 aver loss:0.00026 aver reward:-11.80000 explot:0.01000
# global step:820139 episode :444/1000 aver loss:0.00026 aver reward:-11.60000 explot:0.01000
# global step:822122 episode :445/1000 aver loss:0.00026 aver reward:-11.90000 explot:0.01000
# global step:825083 episode :446/1000 aver loss:0.00026 aver reward:-11.60000 explot:0.01000
# global step:827900 episode :447/1000 aver loss:0.00026 aver reward:-10.70000 explot:0.01000
# global step:829882 episode :448/1000 aver loss:0.00026 aver reward:-11.10000 explot:0.01000
# global step:832759 episode :449/1000 aver loss:0.00027 aver reward:-10.10000 explot:0.01000
# global step:835088 episode :450/1000 aver loss:0.00027 aver reward:-9.80000 explot:0.01000
# global step:837558 episode :451/1000 aver loss:0.00028 aver reward:-10.10000 explot:0.01000
# global step:840197 episode :452/1000 aver loss:0.00029 aver reward:-9.20000 explot:0.01000
# global step:842715 episode :453/1000 aver loss:0.00029 aver reward:-9.80000 explot:0.01000
# global step:845093 episode :454/1000 aver loss:0.00029 aver reward:-10.10000 explot:0.01000
# global step:847318 episode :455/1000 aver loss:0.00029 aver reward:-9.90000 explot:0.01000
# global step:850187 episode :456/1000 aver loss:0.00029 aver reward:-9.60000 explot:0.01000
# global step:851961 episode :457/1000 aver loss:0.00029 aver reward:-10.10000 explot:0.01000
# global step:855098 episode :458/1000 aver loss:0.00029 aver reward:-9.20000 explot:0.01000
# global step:856988 episode :459/1000 aver loss:0.00030 aver reward:-9.80000 explot:0.01000
# global step:859359 episode :460/1000 aver loss:0.00029 aver reward:-9.80000 explot:0.01000
# global step:862250 episode :461/1000 aver loss:0.00029 aver reward:-10.00000 explot:0.01000
# global step:865098 episode :462/1000 aver loss:0.00029 aver reward:-9.60000 explot:0.01000
# global step:868484 episode :463/1000 aver loss:0.00029 aver reward:-8.30000 explot:0.01000
# global step:871433 episode :464/1000 aver loss:0.00030 aver reward:-8.10000 explot:0.01000
# global step:874021 episode :465/1000 aver loss:0.00030 aver reward:-7.90000 explot:0.01000
# global step:876935 episode :466/1000 aver loss:0.00030 aver reward:-7.00000 explot:0.01000
# global step:879732 episode :467/1000 aver loss:0.00030 aver reward:-6.40000 explot:0.01000
# global step:881735 episode :468/1000 aver loss:0.00030 aver reward:-7.60000 explot:0.01000
# global step:884795 episode :469/1000 aver loss:0.00030 aver reward:-7.10000 explot:0.01000
# global step:887815 episode :470/1000 aver loss:0.00030 aver reward:-6.50000 explot:0.01000
# global step:890699 episode :471/1000 aver loss:0.00030 aver reward:-6.30000 explot:0.01000
# global step:893247 episode :472/1000 aver loss:0.00030 aver reward:-7.10000 explot:0.01000
# global step:896145 episode :473/1000 aver loss:0.00031 aver reward:-8.00000 explot:0.01000
# global step:897752 episode :474/1000 aver loss:0.00031 aver reward:-8.80000 explot:0.01000
# global step:899705 episode :475/1000 aver loss:0.00031 aver reward:-9.30000 explot:0.01000
# global step:902751 episode :476/1000 aver loss:0.00032 aver reward:-10.20000 explot:0.01000
# global step:904927 episode :477/1000 aver loss:0.00032 aver reward:-10.60000 explot:0.01000
# global step:907098 episode :478/1000 aver loss:0.00033 aver reward:-10.40000 explot:0.01000
# global step:910236 episode :479/1000 aver loss:0.00033 aver reward:-10.50000 explot:0.01000
# global step:912389 episode :480/1000 aver loss:0.00033 aver reward:-11.00000 explot:0.01000
# global step:915318 episode :481/1000 aver loss:0.00033 aver reward:-11.10000 explot:0.01000
# global step:917361 episode :482/1000 aver loss:0.00033 aver reward:-11.30000 explot:0.01000
# global step:919052 episode :483/1000 aver loss:0.00033 aver reward:-12.20000 explot:0.01000
# global step:921940 episode :484/1000 aver loss:0.00033 aver reward:-11.30000 explot:0.01000
# global step:924618 episode :485/1000 aver loss:0.00033 aver reward:-10.80000 explot:0.01000
# global step:926883 episode :486/1000 aver loss:0.00033 aver reward:-11.30000 explot:0.01000
# global step:929220 episode :487/1000 aver loss:0.00033 aver reward:-11.10000 explot:0.01000
# global step:931726 episode :488/1000 aver loss:0.00032 aver reward:-10.50000 explot:0.01000
# global step:934200 episode :489/1000 aver loss:0.00032 aver reward:-11.00000 explot:0.01000
# global step:936632 episode :490/1000 aver loss:0.00032 aver reward:-11.00000 explot:0.01000
# global step:939620 episode :491/1000 aver loss:0.00032 aver reward:-10.50000 explot:0.01000
# global step:942759 episode :492/1000 aver loss:0.00032 aver reward:-9.60000 explot:0.01000
# global step:945919 episode :493/1000 aver loss:0.00032 aver reward:-8.60000 explot:0.01000
# global step:948097 episode :494/1000 aver loss:0.00032 aver reward:-9.20000 explot:0.01000
# global step:950202 episode :495/1000 aver loss:0.00032 aver reward:-9.60000 explot:0.01000
# global step:953218 episode :496/1000 aver loss:0.00033 aver reward:-9.10000 explot:0.01000
# global step:954753 episode :497/1000 aver loss:0.00033 aver reward:-9.50000 explot:0.01000
# global step:957359 episode :498/1000 aver loss:0.00034 aver reward:-9.60000 explot:0.01000
# global step:960050 episode :499/1000 aver loss:0.00035 aver reward:-9.10000 explot:0.01000
# global step:963223 episode :500/1000 aver loss:0.00036 aver reward:-8.40000 explot:0.01000
# global step:965987 episode :501/1000 aver loss:0.00036 aver reward:-8.70000 explot:0.01000
# global step:968397 episode :502/1000 aver loss:0.00037 aver reward:-9.40000 explot:0.01000
# global step:971144 episode :503/1000 aver loss:0.00038 aver reward:-9.60000 explot:0.01000
# global step:973988 episode :504/1000 aver loss:0.00039 aver reward:-8.80000 explot:0.01000
# global step:976089 episode :505/1000 aver loss:0.00039 aver reward:-8.90000 explot:0.01000
# global step:979314 episode :506/1000 aver loss:0.00040 aver reward:-8.70000 explot:0.01000
# global step:982317 episode :507/1000 aver loss:0.00040 aver reward:-7.70000 explot:0.01000
# global step:985035 episode :508/1000 aver loss:0.00040 aver reward:-7.60000 explot:0.01000
# global step:987310 episode :509/1000 aver loss:0.00041 aver reward:-8.10000 explot:0.01000
# global step:989393 episode :510/1000 aver loss:0.00041 aver reward:-9.50000 explot:0.01000
# global step:991208 episode :511/1000 aver loss:0.00041 aver reward:-10.40000 explot:0.01000
# global step:994106 episode :512/1000 aver loss:0.00042 aver reward:-9.90000 explot:0.01000
# global step:996770 episode :513/1000 aver loss:0.00043 aver reward:-9.80000 explot:0.01000
# global step:998640 episode :514/1000 aver loss:0.00043 aver reward:-11.00000 explot:0.01000
# global step:1001040 episode :515/1000 aver loss:0.00043 aver reward:-10.50000 explot:0.01000
# global step:1003628 episode :516/1000 aver loss:0.00044 aver reward:-11.20000 explot:0.01000
# global step:1005947 episode :517/1000 aver loss:0.00044 aver reward:-12.10000 explot:0.01000
# global step:1008601 episode :518/1000 aver loss:0.00045 aver reward:-12.00000 explot:0.01000
# global step:1010700 episode :519/1000 aver loss:0.00046 aver reward:-12.20000 explot:0.01000
# global step:1013534 episode :520/1000 aver loss:0.00046 aver reward:-11.10000 explot:0.01000
# global step:1016628 episode :521/1000 aver loss:0.00047 aver reward:-10.00000 explot:0.01000
# global step:1018789 episode :522/1000 aver loss:0.00047 aver reward:-10.60000 explot:0.01000
# ...
# global step:1469214 episode :747/1000 aver loss:0.00178 aver reward:-11.40000 explot:0.01000
# global step:1471682 episode :748/1000 aver loss:0.00180 aver reward:-10.90000 explot:0.01000
# global step:1474274 episode :749/1000 aver loss:0.00182 aver reward:-10.10000 explot:0.01000
# global step:1476546 episode :750/1000 aver loss:0.00182 aver reward:-9.90000 explot:0.01000
# global step:1479256 episode :751/1000 aver loss:0.00184 aver reward:-9.70000 explot:0.01000
# global step:1481790 episode :752/1000 aver loss:0.00183 aver reward:-9.70000 explot:0.01000
# global step:1483989 episode :753/1000 aver loss:0.00184 aver reward:-10.50000 explot:0.01000
# global step:1486128 episode :754/1000 aver loss:0.00185 aver reward:-10.50000 explot:0.01000
# global step:1488186 episode :755/1000 aver loss:0.00184 aver reward:-11.00000 explot:0.01000
# global step:1490753 episode :756/1000 aver loss:0.00183 aver reward:-11.20000 explot:0.01000
# global step:1493087 episode :757/1000 aver loss:0.00183 aver reward:-11.70000 explot:0.01000
# global step:1495401 episode :758/1000 aver loss:0.00182 aver reward:-11.50000 explot:0.01000
# global step:1498007 episode :759/1000 aver loss:0.00182 aver reward:-12.00000 explot:0.01000
# global step:1501254 episode :760/1000 aver loss:0.00183 aver reward:-11.10000 explot:0.01000
# global step:1504251 episode :761/1000 aver loss:0.00182 aver reward:-10.70000 explot:0.01000
# global step:1507234 episode :762/1000 aver loss:0.00183 aver reward:-10.20000 explot:0.01000
# global step:1509355 episode :763/1000 aver loss:0.00183 aver reward:-10.50000 explot:0.01000
# global step:1511439 episode :764/1000 aver loss:0.00182 aver reward:-10.40000 explot:0.01000
# global step:1513897 episode :765/1000 aver loss:0.00182 aver reward:-9.80000 explot:0.01000
# global step:1516160 episode :766/1000 aver loss:0.00183 aver reward:-9.80000 explot:0.01000
# global step:1518897 episode :767/1000 aver loss:0.00182 aver reward:-9.30000 explot:0.01000
# global step:1521264 episode :768/1000 aver loss:0.00182 aver reward:-9.50000 explot:0.01000
# global step:1523623 episode :769/1000 aver loss:0.00181 aver reward:-9.40000 explot:0.01000
# global step:1525967 episode :770/1000 aver loss:0.00182 aver reward:-10.20000 explot:0.01000
# global step:1528628 episode :771/1000 aver loss:0.00182 aver reward:-10.50000 explot:0.01000
# global step:1531105 episode :772/1000 aver loss:0.00182 aver reward:-11.10000 explot:0.01000
# global step:1533882 episode :773/1000 aver loss:0.00183 aver reward:-11.00000 explot:0.01000
# global step:1536635 episode :774/1000 aver loss:0.00184 aver reward:-10.80000 explot:0.01000
# global step:1538987 episode :775/1000 aver loss:0.00187 aver reward:-11.00000 explot:0.01000
# global step:1540947 episode :776/1000 aver loss:0.00191 aver reward:-11.40000 explot:0.01000
# global step:1543516 episode :777/1000 aver loss:0.00196 aver reward:-11.70000 explot:0.01000
# global step:1546393 episode :778/1000 aver loss:0.00201 aver reward:-11.10000 explot:0.01000
# global step:1548543 episode :779/1000 aver loss:0.00208 aver reward:-11.30000 explot:0.01000
# global step:1550660 episode :780/1000 aver loss:0.00215 aver reward:-11.30000 explot:0.01000
# global step:1553771 episode :781/1000 aver loss:0.00224 aver reward:-11.10000 explot:0.01000
# global step:1556213 episode :782/1000 aver loss:0.00232 aver reward:-11.00000 explot:0.01000
# global step:1558932 episode :783/1000 aver loss:0.00241 aver reward:-10.20000 explot:0.01000
# global step:1561336 episode :784/1000 aver loss:0.00248 aver reward:-10.30000 explot:0.01000
# global step:1563569 episode :785/1000 aver loss:0.00255 aver reward:-10.50000 explot:0.01000
# global step:1565481 episode :786/1000 aver loss:0.00263 aver reward:-10.40000 explot:0.01000
# global step:1567855 episode :787/1000 aver loss:0.00266 aver reward:-10.50000 explot:0.01000
# global step:1570595 episode :788/1000 aver loss:0.00270 aver reward:-10.50000 explot:0.01000
# global step:1573001 episode :789/1000 aver loss:0.00271 aver reward:-10.00000 explot:0.01000
# global step:1575631 episode :790/1000 aver loss:0.00273 aver reward:-10.00000 explot:0.01000
# global step:1578529 episode :791/1000 aver loss:0.00272 aver reward:-9.90000 explot:0.01000
# global step:1580756 episode :792/1000 aver loss:0.00271 aver reward:-10.10000 explot:0.01000
# global step:1583809 episode :793/1000 aver loss:0.00268 aver reward:-10.20000 explot:0.01000
# global step:1586535 episode :794/1000 aver loss:0.00265 aver reward:-9.40000 explot:0.01000
# global step:1589284 episode :795/1000 aver loss:0.00260 aver reward:-8.60000 explot:0.01000
# global step:1591843 episode :796/1000 aver loss:0.00254 aver reward:-8.00000 explot:0.01000
# global step:1594372 episode :797/1000 aver loss:0.00251 aver reward:-8.10000 explot:0.01000
# global step:1596635 episode :798/1000 aver loss:0.00248 aver reward:-8.40000 explot:0.01000
# global step:1599037 episode :799/1000 aver loss:0.00249 aver reward:-8.40000 explot:0.01000
# global step:1601874 episode :800/1000 aver loss:0.00249 aver reward:-8.10000 explot:0.01000
# global step:1603836 episode :801/1000 aver loss:0.00252 aver reward:-8.40000 explot:0.01000
# global step:1605937 episode :802/1000 aver loss:0.00253 aver reward:-8.50000 explot:0.01000
# global step:1608441 episode :803/1000 aver loss:0.00255 aver reward:-8.80000 explot:0.01000
# global step:1611210 episode :804/1000 aver loss:0.00257 aver reward:-9.40000 explot:0.01000
# global step:1613524 episode :805/1000 aver loss:0.00259 aver reward:-10.10000 explot:0.01000
# global step:1616234 episode :806/1000 aver loss:0.00261 aver reward:-10.00000 explot:0.01000
# global step:1619164 episode :807/1000 aver loss:0.00261 aver reward:-9.40000 explot:0.01000
# global step:1621777 episode :808/1000 aver loss:0.00260 aver reward:-9.10000 explot:0.01000
# global step:1624565 episode :809/1000 aver loss:0.00257 aver reward:-8.90000 explot:0.01000
# global step:1627239 episode :810/1000 aver loss:0.00252 aver reward:-8.80000 explot:0.01000
# global step:1629681 episode :811/1000 aver loss:0.00246 aver reward:-8.90000 explot:0.01000
# global step:1632827 episode :812/1000 aver loss:0.00243 aver reward:-8.30000 explot:0.01000
# global step:1635629 episode :813/1000 aver loss:0.00240 aver reward:-8.00000 explot:0.01000
# global step:1638139 episode :814/1000 aver loss:0.00240 aver reward:-8.00000 explot:0.01000
# global step:1640165 episode :815/1000 aver loss:0.00241 aver reward:-8.30000 explot:0.01000
# global step:1642371 episode :816/1000 aver loss:0.00240 aver reward:-8.70000 explot:0.01000
# global step:1644749 episode :817/1000 aver loss:0.00241 aver reward:-9.70000 explot:0.01000
# global step:1647035 episode :818/1000 aver loss:0.00244 aver reward:-10.40000 explot:0.01000
# global step:1649689 episode :819/1000 aver loss:0.00246 aver reward:-10.30000 explot:0.01000
# global step:1652677 episode :820/1000 aver loss:0.00246 aver reward:-10.10000 explot:0.01000
# global step:1655268 episode :821/1000 aver loss:0.00247 aver reward:-10.00000 explot:0.01000
# global step:1658404 episode :822/1000 aver loss:0.00247 aver reward:-10.00000 explot:0.01000
# global step:1661433 episode :823/1000 aver loss:0.00247 aver reward:-10.30000 explot:0.01000
# global step:1663904 episode :824/1000 aver loss:0.00245 aver reward:-10.40000 explot:0.01000
# global step:1666618 episode :825/1000 aver loss:0.00240 aver reward:-10.00000 explot:0.01000
# global step:1669286 episode :826/1000 aver loss:0.00236 aver reward:-9.80000 explot:0.01000
# global step:1671920 episode :827/1000 aver loss:0.00232 aver reward:-9.60000 explot:0.01000
# global step:1675243 episode :828/1000 aver loss:0.00226 aver reward:-8.70000 explot:0.01000
# global step:1677454 episode :829/1000 aver loss:0.00221 aver reward:-9.10000 explot:0.01000
# global step:1680050 episode :830/1000 aver loss:0.00218 aver reward:-9.20000 explot:0.01000
# global step:1682668 episode :831/1000 aver loss:0.00215 aver reward:-9.50000 explot:0.01000
# global step:1684355 episode :832/1000 aver loss:0.00213 aver reward:-10.40000 explot:0.01000
# global step:1686820 episode :833/1000 aver loss:0.00213 aver reward:-10.80000 explot:0.01000
# global step:1689392 episode :834/1000 aver loss:0.00215 aver reward:-10.50000 explot:0.01000
# global step:1692469 episode :835/1000 aver loss:0.00216 aver reward:-10.10000 explot:0.01000
# global step:1695076 episode :836/1000 aver loss:0.00216 aver reward:-10.40000 explot:0.01000
# global step:1698340 episode :837/1000 aver loss:0.00215 aver reward:-9.80000 explot:0.01000
# global step:1701327 episode :838/1000 aver loss:0.00213 aver reward:-10.00000 explot:0.01000
# global step:1704271 episode :839/1000 aver loss:0.00210 aver reward:-9.40000 explot:0.01000
# global step:1706940 episode :840/1000 aver loss:0.00210 aver reward:-10.00000 explot:0.01000
# global step:1710117 episode :841/1000 aver loss:0.00208 aver reward:-8.90000 explot:0.01000
# global step:1712807 episode :842/1000 aver loss:0.00205 aver reward:-8.40000 explot:0.01000
# global step:1715681 episode :843/1000 aver loss:0.00204 aver reward:-7.60000 explot:0.01000
# global step:1718664 episode :844/1000 aver loss:0.00200 aver reward:-7.70000 explot:0.01000
# global step:1721585 episode :845/1000 aver loss:0.00197 aver reward:-7.70000 explot:0.01000
# global step:1723657 episode :846/1000 aver loss:0.00197 aver reward:-7.90000 explot:0.01000
# global step:1726171 episode :847/1000 aver loss:0.00197 aver reward:-8.60000 explot:0.01000
# global step:1728973 episode :848/1000 aver loss:0.00199 aver reward:-8.60000 explot:0.01000
# global step:1732477 episode :849/1000 aver loss:0.00203 aver reward:-8.70000 explot:0.01000
# global step:1735074 episode :850/1000 aver loss:0.00208 aver reward:-8.50000 explot:0.01000
# global step:1736999 episode :851/1000 aver loss:0.00212 aver reward:-10.00000 explot:0.01000
# global step:1740240 episode :852/1000 aver loss:0.00215 aver reward:-9.70000 explot:0.01000
# global step:1743029 episode :853/1000 aver loss:0.00215 aver reward:-9.90000 explot:0.01000
# global step:1745181 episode :854/1000 aver loss:0.00216 aver reward:-10.60000 explot:0.01000
# global step:1747630 episode :855/1000 aver loss:0.00220 aver reward:-10.90000 explot:0.01000
# global step:1750848 episode :856/1000 aver loss:0.00224 aver reward:-9.60000 explot:0.01000
# global step:1754201 episode :857/1000 aver loss:0.00227 aver reward:-8.80000 explot:0.01000
# global step:1756779 episode :858/1000 aver loss:0.00230 aver reward:-9.00000 explot:0.01000
# global step:1759127 episode :859/1000 aver loss:0.00232 aver reward:-10.00000 explot:0.01000
# global step:1762100 episode :860/1000 aver loss:0.00232 aver reward:-9.70000 explot:0.01000
# global step:1764222 episode :861/1000 aver loss:0.00231 aver reward:-9.30000 explot:0.01000
# global step:1767255 episode :862/1000 aver loss:0.00231 aver reward:-9.00000 explot:0.01000
# global step:1770100 episode :863/1000 aver loss:0.00232 aver reward:-9.10000 explot:0.01000
# global step:1772589 episode :864/1000 aver loss:0.00233 aver reward:-8.90000 explot:0.01000
# global step:1774846 episode :865/1000 aver loss:0.00234 aver reward:-9.10000 explot:0.01000
# global step:1778068 episode :866/1000 aver loss:0.00236 aver reward:-9.70000 explot:0.01000
# global step:1781198 episode :867/1000 aver loss:0.00236 aver reward:-9.90000 explot:0.01000
# global step:1783358 episode :868/1000 aver loss:0.00236 aver reward:-9.90000 explot:0.01000
# global step:1786137 episode :869/1000 aver loss:0.00234 aver reward:-9.20000 explot:0.01000
# global step:1789163 episode :870/1000 aver loss:0.00231 aver reward:-9.20000 explot:0.01000
# global step:1791745 episode :871/1000 aver loss:0.00230 aver reward:-9.10000 explot:0.01000
# global step:1795206 episode :872/1000 aver loss:0.00229 aver reward:-8.90000 explot:0.01000
# global step:1798104 episode :873/1000 aver loss:0.00227 aver reward:-9.10000 explot:0.01000
# global step:1800069 episode :874/1000 aver loss:0.00226 aver reward:-9.10000 explot:0.01000
# global step:1802954 episode :875/1000 aver loss:0.00223 aver reward:-8.90000 explot:0.01000
# global step:1805913 episode :876/1000 aver loss:0.00217 aver reward:-8.90000 explot:0.01000
# global step:1808952 episode :877/1000 aver loss:0.00214 aver reward:-8.80000 explot:0.01000
# global step:1811730 episode :878/1000 aver loss:0.00212 aver reward:-8.40000 explot:0.01000
# global step:1814738 episode :879/1000 aver loss:0.00214 aver reward:-8.20000 explot:0.01000
# global step:1817226 episode :880/1000 aver loss:0.00218 aver reward:-8.40000 explot:0.01000
# global step:1820154 episode :881/1000 aver loss:0.00219 aver reward:-8.20000 explot:0.01000
# global step:1823448 episode :882/1000 aver loss:0.00218 aver reward:-8.70000 explot:0.01000
# global step:1826116 episode :883/1000 aver loss:0.00216 aver reward:-8.50000 explot:0.01000
# global step:1827381 episode :884/1000 aver loss:0.00216 aver reward:-9.10000 explot:0.01000
# global step:1828761 episode :885/1000 aver loss:0.00216 aver reward:-9.90000 explot:0.01000
# global step:1832071 episode :886/1000 aver loss:0.00219 aver reward:-9.70000 explot:0.01000
# global step:1834846 episode :887/1000 aver loss:0.00220 aver reward:-9.90000 explot:0.01000
# global step:1836762 episode :888/1000 aver loss:0.00218 aver reward:-11.00000 explot:0.01000
# global step:1840212 episode :889/1000 aver loss:0.00215 aver reward:-10.70000 explot:0.01000
# global step:1843124 episode :890/1000 aver loss:0.00213 aver reward:-10.60000 explot:0.01000
# global step:1846123 episode :891/1000 aver loss:0.00214 aver reward:-10.30000 explot:0.01000
# global step:1848912 episode :892/1000 aver loss:0.00215 aver reward:-10.30000 explot:0.01000
# global step:1851538 episode :893/1000 aver loss:0.00218 aver reward:-10.40000 explot:0.01000
# global step:1854421 episode :894/1000 aver loss:0.00221 aver reward:-9.70000 explot:0.01000
# global step:1856192 episode :895/1000 aver loss:0.00225 aver reward:-9.60000 explot:0.01000
# global step:1858681 episode :896/1000 aver loss:0.00228 aver reward:-10.20000 explot:0.01000
# global step:1861065 episode :897/1000 aver loss:0.00232 aver reward:-10.80000 explot:0.01000
# global step:1864114 episode :898/1000 aver loss:0.00234 aver reward:-9.80000 explot:0.01000
# global step:1866917 episode :899/1000 aver loss:0.00236 aver reward:-10.30000 explot:0.01000
# global step:1869886 episode :900/1000 aver loss:0.00236 aver reward:-10.30000 explot:0.01000
# global step:1872479 episode :901/1000 aver loss:0.00237 aver reward:-10.60000 explot:0.01000
# global step:1875761 episode :902/1000 aver loss:0.00237 aver reward:-9.90000 explot:0.01000
# global step:1877875 episode :903/1000 aver loss:0.00235 aver reward:-10.30000 explot:0.01000
# global step:1881345 episode :904/1000 aver loss:0.00233 aver reward:-9.40000 explot:0.01000
# global step:1884619 episode :905/1000 aver loss:0.00232 aver reward:-8.60000 explot:0.01000
# global step:1886966 episode :906/1000 aver loss:0.00229 aver reward:-8.80000 explot:0.01000
# global step:1889826 episode :907/1000 aver loss:0.00229 aver reward:-8.00000 explot:0.01000
# global step:1893331 episode :908/1000 aver loss:0.00228 aver reward:-7.40000 explot:0.01000
# global step:1896029 episode :909/1000 aver loss:0.00231 aver reward:-7.70000 explot:0.01000
# global step:1899066 episode :910/1000 aver loss:0.00238 aver reward:-7.50000 explot:0.01000
# global step:1902179 episode :911/1000 aver loss:0.00243 aver reward:-7.20000 explot:0.01000
# global step:1904699 episode :912/1000 aver loss:0.00249 aver reward:-7.90000 explot:0.01000
# global step:1907908 episode :913/1000 aver loss:0.00254 aver reward:-7.40000 explot:0.01000
# global step:1910081 episode :914/1000 aver loss:0.00259 aver reward:-8.40000 explot:0.01000
# global step:1912964 episode :915/1000 aver loss:0.00263 aver reward:-8.00000 explot:0.01000
# global step:1915571 episode :916/1000 aver loss:0.00269 aver reward:-7.90000 explot:0.01000
# global step:1917729 episode :917/1000 aver loss:0.00273 aver reward:-9.00000 explot:0.01000
# global step:1920244 episode :918/1000 aver loss:0.00279 aver reward:-9.80000 explot:0.01000
# global step:1923015 episode :919/1000 aver loss:0.00283 aver reward:-9.70000 explot:0.01000

# %%
# plot loss and rewards
import matplotlib.pyplot as plt
def plot_(losses, rewards):
    plt.figure()
    plt.title('rewards')
    plt.plot(list(range(len(rewards))), rewards)
    
    plt.figure()
    plt.title('loss')
    plt.plot(list(range(len(losses))),losses)
    plt.show()

plot_(losses, rewards)
