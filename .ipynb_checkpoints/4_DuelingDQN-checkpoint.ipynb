# %% [markdown]
# ## Dueling DQN
#
# ### principle：
# $Q(s,a|\theta ,\beta ,\alpha ) = V(s|\theta ,\beta ) + A(s,a|\theta ,\alpha )$
#
# ### actually：
# $Q(s,a|\theta ,\beta ,\alpha ) = V(s|\theta ,\beta ) + A(s,a|\theta ,\alpha ) - {1 \over {|A|}}\sum\limits_{a'} {A(s,a'|\theta ,\alpha )} $
#
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### discussion
#
# ### reference:
# https://www.cnblogs.com/xxxxxxxxx/p/12034554.html

# %%
import numpy as np
import torch
from torch import nn, optim
import os
import matplotlib.pyplot as plt
from atari_wrappers import make_atari, wrap_deepmind,LazyFrames

# %%
# preprocess
def prepro(obs):
    """
    preprocess observation 
    [84,84,4]=>[4,84,84]
    """
    obs = obs._force().transpose(2,0,1)/255  # 0-255 => 0-1, [84,84,4] => [4,84,84]
    return obs

# %%
# net
import torch
from torch import nn
class Net(nn.Module):
    """
    Initialize a deep Q-learning network as described in
    https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
    Arguments:
        in_channels: number of channel of input.
            i.e The number of most recent frames stacked together as describe in the paper
        out_num: number of action-value to output, one-to-one correspondence to action in game.
    """
    def __init__(self, in_channel=4, out_num=6):
        super(Net,self).__init__()
        # layer setting paramters
        layers = [32,64,64]
        # output_size = (input_size-kernel_size)/stride + 1
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channel,layers[0],kernel_size=8,stride=4), # [batch,4,84,84]=>[batch,layers[0],20,20] 
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(layers[0],layers[1],kernel_size=4,stride=2), # [batch,layers[0],20,20]=>[batch,layers[1],9,9]
            nn.ReLU(),
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(layers[1],layers[2],kernel_size=3,stride=1), # [batch,layers[1],9,9]=>[batch,layers[2],7,7]
            nn.ReLU(),
        )
        self.linear1 = nn.Sequential(
            nn.Linear(7*7*layers[2], 512),
            nn.ReLU()
        )
        self.linear_value = nn.Linear(256, 1)  # value
        self.linear_a = nn.Linear(256, out_num) # advantage
#         self.linear2 = nn.linear(512, out_num)  # for target
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # flatten
        x = x.reshape(x.size(0), -1)  # [batch, layers[2],7,7]=>[batch,layers[2]*7*7]
        x = self.linear1(x)  # [batch,-1]=>[batch,512]
        x_value = x[:,:256]  # half part for value fullconnect [batch,256]
        x_a = x[:,256:]      # half part for advantage fullconnect [batch,256]
        y_value = self.linear_value(x_value)
        y_a = self.linear_a(x_a)
        # y = F.softmax(y)  # turn to probability
        return y_value, y_a
pre_net = Net()
print(pre_net)
# Out:
# Net(
#   (conv1): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#   )
#   (linear1): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#   )
#   (linear_value): Linear(in_features=256, out_features=1, bias=True)
#   (linear_a): Linear(in_features=256, out_features=6, bias=True)
# )

# %%
class SumTree():
    data_point = 0  # data idx
    def __init__(self, capacity):
        self.capacity = capacity  # num of leaves
        self.tree = np.zeros(capacity*2-1)
        self.transition = np.zeros(capacity, dtype=object) # save data
        self.n_entries = 0
        
    def total_p(self):
        return self.tree[0]  # return the 0 node
        
    def add(self, p, data):
        # add data and priority
        # p: priority, data 
        idx = self.data_point + self.capacity -1
        self.transition[self.data_point] = data   # save data        
        self.data_point += 1
        if self.data_point >= self.capacity:
            self.data_point = 0            
        
        change = p - self.tree[idx]   
        self.tree[idx] = p            # save priority
        self.n_entries += 1   # count num of entries
        
        # propagation  update parents nodes
        p_idx = (idx-1)//2  # parent idx
        while True:           
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def update(self,idx, p):
        # update tree
        change = p - self.tree[idx]
        self.tree[idx] = p  # change priority in leaves node        
        # update parents node
        p_idx = (idx-1)//2   #
        while True:            
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def retrieve(self, p_idx, s):
        # search leaf idx for s        
        while True:
            l_idx = p_idx*2 + 1  # left child idx
            r_idx = l_idx +1     # right child idx  
            if l_idx >= self.capacity*2-1: # 其子节点超出，结点序号范围， 说明已经是叶子结点
                return p_idx 
            if self.tree[l_idx] >= s:
                p_idx = l_idx
            else:
                p_idx = r_idx
                s -= self.tree[l_idx]
            
    def get(self, s):
        # get a data and priority from tree and transition        
        # get idx of leaves
        idx = self.retrieve(0,s)
        priority = self.tree[idx]
        data_idx = idx - (self.capacity - 1)
        data = self.transition[data_idx]
        return idx, priority, data

# %%
# memory buffer replay
class Memory_buffer_replay():
    beta = 0.4
    beta_increment_per_sampling = 0.001
    abs_err_upper = 1.
    def __init__(self, capacity, device):
        self.capacity = capacity
        self.sumtree = SumTree(self.capacity)
        self.device = device
        
        self.e = 0.01
        self.a = 0.6
        self.prio_max = 0.1
        
    def store_record(self, state, state_next, a, r, done):
        data = (state, state_next, a, r, done)
        priority = (np.abs(self.prio_max) + self.e) ** self.a #  proportional priority
        self.sumtree.add(priority, data) # save p, data in sumtree
        
    def sample(self, batchsz):
        if self.sumtree.total_p()==0:
            return None
        states, state_nexts, a_s, r_s, done_s = [],[],[],[],[]
        idxs, ps, isweights = [],[],[]  # idss, prioritys
        segment = self.sumtree.total_p()/batchsz
        
        self.beta = np.min([1., self.beta+self.beta_increment_per_sampling])
        min_prob = np.min(self.sumtree.tree[-self.capacity:])/self.sumtree.total_p()
        
        for i in range(batchsz):
            down_bound = i*segment
            up_bound = (i+1)*segment
            s = np.random.uniform(down_bound, up_bound)
            idx, p, data = self.sumtree.get(s) 
            
            state, state_next, a, r, done = data
            prob = p/self.sumtree.total_p()
            isweight = np.power(prob/min_prob, -self.beta)
            
            isweights.append(isweight)
            idxs.append(idx)
            ps.append(p)
            states.append(state)
            state_nexts.append(state_next)
            a_s.append(a)
            r_s.append(r)
            done_s.append(done)
        
        #from list to numpy
#         idxs, ps = np.array(idxs), np.array(ps)
        # function: list=> tensor
        list2tensor = lambda data: torch.from_numpy(np.array(data)).to(self.device)
        
        isweights = list2tensor(isweights)
        states, state_nexts = list2tensor(states), list2tensor(state_nexts)
        a_s, r_s, done_s = list2tensor(a_s), list2tensor(r_s), list2tensor(done_s)
        # isweights: tensor, idx:list, ps:list, states:tensor, as, rs, done_s:tensor
        return isweights, idxs, ps, states, state_nexts, a_s, r_s, done_s
    
    def update(self, idxs, errors):
        # update data priority
        self.prio_max = max(self.prio_max, max(np.abs(errors)))
        for i, idx in enumerate(idxs):
            p = (np.abs(errors[i]) + self.e) ** self.a
            self.sumtree.update(idx, p)

# %%
# DQN with priority
import torch.nn.functional as F
class DQN_priority():
    def __init__(self, args, env, load_model=False):        
        # use cuda
        cuda = True
        if cuda:
            self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        else:
            self.device = torch.device('cpu')
            
        # env
        self.env = env
        self.n_actions = env.action_space.n
        self.dim_shape = env.observation_space.shape
        
        # hyperparams
        self.capacity = 100000
        self.decay = 0.99
        self.episodes = args.episodes
        self.log_interval = args.log_interval  # print state per log_interval epsisode
        self.save_interval = args.save_interval  # interval for save model 
        
        self.epilon_max = 1
        self.epilon_min = 0.01
        self.learning_start = 10000  # 装满10000 再开始
        self.epilon_decay = 30000
        
        # learn params
        self.lr = args.lr
        self.batchsz = args.batchsz
        self.iter =0
        self.iter_max = args.iter_max
        
        # build model
        self.eval_model = Net().to(self.device)
        self.tar_model = Net().to(self.device)  
        # load model
        if load_model:
            self.eval_model.load_state_dict(torch.load('dqn_priority.mdl'))
        self.tar_model.load_state_dict(self.eval_model.state_dict())
        # build optimizer
        self.optimizer = optim.RMSprop(self.eval_model.parameters(),lr=self.lr, eps=0.001, alpha=0.95)
#         self.optimizer = optim.Adam(self.eval_model.parameters(), self.lr)
#         self.cost_F = nn.MSELoss()
        
        # build memory buffer
        self.buffer = Memory_buffer_replay(self.capacity, self.device)
    
    def train(self):
        episodes = self.episodes
        losses = []
        rewards  = []
        
        # decay function explot ratio
        epilon_by_g_step = lambda step_idx:self.epilon_min + (self.epilon_max-self.epilon_min)*np.exp(-1*step_idx/self.epilon_decay)
        # global step
        global_step = 0
        
        for epis in range(episodes):
            state = self.env.reset()
            state = prepro(state) # [84,84,4]=>[4,84,84]
            reward_sum = 0
            loss_ = []
            # decay explot ratio
#             self.explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/50.)
            while True:
                # decay explot ratio
                epsilon = epilon_by_g_step(global_step)
                global_step += 1 
                act = self.make_action(state, epsilon) # choose action
                state_next, r, done, inf = self.env.step(act)
                state_next = prepro(state_next)
                reward_sum += r                
                # store data
                self.buffer.store_record(state, state_next, act, r, done)                
                if done:                    
                    rewards.append(reward_sum)
                    losses.append(np.mean(loss_))
                    break  # start another episode
                else:
                    state = state_next
            
                # learn model
                if self.buffer.sumtree.n_entries == self.learning_start:
                    print('#'*30 + 'start learning' + '#'*30)
                if self.buffer.sumtree.n_entries > self.learning_start:
                    loss = self.learn()
                    loss_.append(loss)
                else:
                    loss_.append(0)
                
            # print train state
            if epis%self.log_interval==0 and epis>0:
                #print(losses)
                print('global step:{}'.format(global_step-1),
                      'episode :{}/{}'.format(epis, self.episodes), 
                      'aver loss:{:.5f}'.format(np.mean(losses[-10:])), 
                      'aver reward:{:.5f}'.format(np.mean(rewards[-10:])),
                      'explot:{:.5f}'.format(epsilon)
                     )
            # save model
            if epis%self.save_interval==0 and epis>0:
                torch.save(self.eval_model.state_dict(),'dqn_priority.mdl')
        return losses, rewards
    
    def learn(self):
        # learn the model
        
        # get data,  idxs, ps : list. others tensor
        isweights, idxs, ps, state, state_next, act_s, r_s, done_s = self.buffer.sample(self.batchsz)        
        
        # pre
        eval_v,eval_a = self.eval_model(state.float())
        eval_v = eval_v.view(-1) # colum vector => row vector        
        eval_q = eval_v + eval_a.gather(1,act_s.unsqueeze(1).long()).squeeze(1) + eval_a.mean(1) #      
        eval_q = eval_q.squeeze(-1)  # [batch,1] => [batch]
        # compute label
        next_q_v, next_q_a = self.tar_model(state_next.float()) 
        next_q_v = next_q_v.view(-1)
        next_max_q = (next_q_v + next_q_a.max(1)[0] - next_q_a.mean(1)).detach() # torch.max() return [max_data, max_idx]
        next_max_q = next_max_q.squeeze(-1) 
        decay = torch.tensor(self.decay).float().to(self.device)
        tar_q = r_s.float() + decay*next_max_q
        tar_q = torch.where(done_s>0, r_s.float(), tar_q)  # Q_next = r when done is true
        
        #compute td-loss
        loss = F.smooth_l1_loss(eval_q, tar_q)
#         loss = torch.mean(isweights*torch.abs(eval_q - tar_q)) # loss expect input dim=[batch,1]
        # update buffer with error
        errors = (eval_q - tar_q).detach().cpu().tolist()
        self.buffer.update(idxs, errors)
        
        self.optimizer.zero_grad()
        loss.backward()
        # clip gradient
        for param in self.eval_model.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        
        # update tar_model
        self.iter += 1
        if self.iter%self.iter_max==0:
            self.tar_model.load_state_dict(self.eval_model.state_dict())
        
        return loss.cpu().item() # ruturn mean loss
    
    def make_action(self, state, epsilon=None):
        state = torch.from_numpy(state).float()
        
        pre_q_v, pre_q_a = self.eval_model(state.unsqueeze(0).to(self.device))
        pre_q_a = pre_q_a.cpu().detach()
        
        #explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/20.)
        if epsilon==None:
            epsilon=self.epsion_min
        if np.random.uniform()< epsilon:
            action = np.random.choice(self.n_actions) # random choose action
        else:
            action = torch.argmax(pre_q_a)
            action = action.item()
        return action

# %%
# argument
class Argument():
    def __init__(self):
        self.lr = 1e-3
        self.batchsz = 32
        
        self.episodes = 1000
        
        self.log_interval = 1 # print state per log_interval epsisode
        self.save_interval = 20  # interval for save model
        
        self.iter_max = 1000  # update tar_model interval

args = Argument()

# %%
# main
import gym
env = make_atari('PongNoFrameskip-v4') # only use in no frameskip environment
env = wrap_deepmind(env, scale = False, frame_stack=True )

load_model = False
run_dqn = DQN_priority(args, env, load_model)
losses, rewards = run_dqn.train()
# Out:
# global step:1725 episode :1/300 aver loss:0.00000 aver reward:-21.00000 explot:0.94468
# global step:2540 episode :2/300 aver loss:0.00000 aver reward:-21.00000 explot:0.91963
# global step:3499 episode :3/300 aver loss:0.00000 aver reward:-20.75000 explot:0.89101
# global step:4376 episode :4/300 aver loss:0.00000 aver reward:-20.80000 explot:0.86563
# global step:5242 episode :5/300 aver loss:0.00000 aver reward:-20.66667 explot:0.84128
# global step:6223 episode :6/300 aver loss:0.00000 aver reward:-20.71429 explot:0.81454
# global step:7434 episode :7/300 aver loss:0.00000 aver reward:-20.50000 explot:0.78271
# global step:8209 episode :8/300 aver loss:0.00000 aver reward:-20.55556 explot:0.76300
# global step:8966 episode :9/300 aver loss:0.00000 aver reward:-20.60000 explot:0.74424
# global step:9815 episode :10/300 aver loss:0.00000 aver reward:-20.60000 explot:0.72375
# ##############################start learning##############################
# /home/ryzen/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
# global step:10577 episode :11/300 aver loss:0.00235 aver reward:-20.60000 explot:0.70585
# global step:11570 episode :12/300 aver loss:0.00570 aver reward:-20.40000 explot:0.68320
# global step:12463 episode :13/300 aver loss:0.00653 aver reward:-20.50000 explot:0.66345
# global step:13461 episode :14/300 aver loss:0.00695 aver reward:-20.50000 explot:0.64207
# global step:14331 episode :15/300 aver loss:0.00729 aver reward:-20.50000 explot:0.62401
# global step:15500 episode :16/300 aver loss:0.00755 aver reward:-20.30000 explot:0.60054
# global step:16431 episode :17/300 aver loss:0.00785 aver reward:-20.40000 explot:0.58250
# global step:17325 episode :18/300 aver loss:0.00806 aver reward:-20.40000 explot:0.56569
# global step:18136 episode :19/300 aver loss:0.00818 aver reward:-20.40000 explot:0.55087
# global step:18975 episode :20/300 aver loss:0.00830 aver reward:-20.40000 explot:0.53595
# global step:19750 episode :21/300 aver loss:0.00605 aver reward:-20.40000 explot:0.52254
# global step:20710 episode :22/300 aver loss:0.00282 aver reward:-20.40000 explot:0.50639
# global step:21469 episode :23/300 aver loss:0.00210 aver reward:-20.40000 explot:0.49399
# global step:22452 episode :24/300 aver loss:0.00178 aver reward:-20.30000 explot:0.47839
# global step:23274 episode :25/300 aver loss:0.00153 aver reward:-20.40000 explot:0.46573
# global step:24260 episode :26/300 aver loss:0.00135 aver reward:-20.60000 explot:0.45100
# global step:25017 episode :27/300 aver loss:0.00113 aver reward:-20.70000 explot:0.44001
# global step:26016 episode :28/300 aver loss:0.00098 aver reward:-20.70000 explot:0.42592
# global step:26838 episode :29/300 aver loss:0.00093 aver reward:-20.70000 explot:0.41468
# global step:27762 episode :30/300 aver loss:0.00087 aver reward:-20.70000 explot:0.40241
# global step:28584 episode :31/300 aver loss:0.00081 aver reward:-20.70000 explot:0.39180
# global step:29518 episode :32/300 aver loss:0.00075 aver reward:-20.80000 explot:0.38010
# global step:30442 episode :33/300 aver loss:0.00069 aver reward:-20.70000 explot:0.36887
# global step:31439 episode :34/300 aver loss:0.00064 aver reward:-20.60000 explot:0.35714
# global step:32215 episode :35/300 aver loss:0.00063 aver reward:-20.60000 explot:0.34828
# global step:33153 episode :36/300 aver loss:0.00062 aver reward:-20.50000 explot:0.33787
# global step:34033 episode :37/300 aver loss:0.00060 aver reward:-20.50000 explot:0.32839
# global step:34989 episode :38/300 aver loss:0.00061 aver reward:-20.40000 explot:0.31840
# global step:35889 episode :39/300 aver loss:0.00061 aver reward:-20.40000 explot:0.30929
# global step:36709 episode :40/300 aver loss:0.00060 aver reward:-20.40000 explot:0.30122
# global step:37654 episode :41/300 aver loss:0.00061 aver reward:-20.30000 explot:0.29219
# global step:38565 episode :42/300 aver loss:0.00062 aver reward:-20.40000 explot:0.28375
# global step:39440 episode :43/300 aver loss:0.00062 aver reward:-20.50000 explot:0.27588
# global step:40407 episode :44/300 aver loss:0.00062 aver reward:-20.70000 explot:0.26744
# global step:41408 episode :45/300 aver loss:0.00061 aver reward:-20.70000 explot:0.25900
# global step:42241 episode :46/300 aver loss:0.00060 aver reward:-20.80000 explot:0.25218
# global step:43196 episode :47/300 aver loss:0.00060 aver reward:-20.80000 explot:0.24459
# global step:44071 episode :48/300 aver loss:0.00060 aver reward:-20.90000 explot:0.23785
# global step:45009 episode :49/300 aver loss:0.00059 aver reward:-20.90000 explot:0.23083
# global step:45884 episode :50/300 aver loss:0.00059 aver reward:-20.80000 explot:0.22448
# global step:46874 episode :51/300 aver loss:0.00058 aver reward:-20.70000 explot:0.21752
# global step:47869 episode :52/300 aver loss:0.00057 aver reward:-20.50000 explot:0.21075
# global step:48705 episode :53/300 aver loss:0.00057 aver reward:-20.50000 explot:0.20524
# global step:49551 episode :54/300 aver loss:0.00056 aver reward:-20.50000 explot:0.19981
# global step:50528 episode :55/300 aver loss:0.00055 aver reward:-20.30000 explot:0.19372
# global step:51446 episode :56/300 aver loss:0.00054 aver reward:-20.20000 explot:0.18819
# global step:52264 episode :57/300 aver loss:0.00053 aver reward:-20.20000 explot:0.18339
# global step:53121 episode :58/300 aver loss:0.00051 aver reward:-20.10000 explot:0.17851
# global step:54101 episode :59/300 aver loss:0.00049 aver reward:-20.00000 explot:0.17310
# global step:55060 episode :60/300 aver loss:0.00048 aver reward:-20.00000 explot:0.16796
# global step:55868 episode :61/300 aver loss:0.00047 aver reward:-20.20000 explot:0.16377
# global step:56799 episode :62/300 aver loss:0.00047 aver reward:-20.40000 explot:0.15907
# global step:57858 episode :63/300 aver loss:0.00047 aver reward:-20.20000 explot:0.15390
# global step:58815 episode :64/300 aver loss:0.00046 aver reward:-20.20000 explot:0.14938
# global step:59880 episode :65/300 aver loss:0.00046 aver reward:-20.20000 explot:0.14452
# global step:60792 episode :66/300 aver loss:0.00045 aver reward:-20.20000 explot:0.14049
# global step:61891 episode :67/300 aver loss:0.00044 aver reward:-20.00000 explot:0.13580
# global step:62828 episode :68/300 aver loss:0.00044 aver reward:-20.10000 explot:0.13193
# global step:63785 episode :69/300 aver loss:0.00043 aver reward:-20.20000 explot:0.12810
# global step:64921 episode :70/300 aver loss:0.00043 aver reward:-20.00000 explot:0.12371
# global step:66179 episode :71/300 aver loss:0.00045 aver reward:-20.00000 explot:0.11904
# global step:67272 episode :72/300 aver loss:0.00046 aver reward:-19.90000 explot:0.11514
# global step:68307 episode :73/300 aver loss:0.00046 aver reward:-20.00000 explot:0.11158
# global step:69126 episode :74/300 aver loss:0.00045 aver reward:-20.00000 explot:0.10884
# global step:70264 episode :75/300 aver loss:0.00046 aver reward:-20.00000 explot:0.10516
# global step:71114 episode :76/300 aver loss:0.00046 aver reward:-20.10000 explot:0.10250
# global step:72081 episode :77/300 aver loss:0.00046 aver reward:-20.30000 explot:0.09957
# global step:73517 episode :78/300 aver loss:0.00046 aver reward:-20.20000 explot:0.09538
# global step:74764 episode :79/300 aver loss:0.00047 aver reward:-20.00000 explot:0.09191
# global step:75788 episode :80/300 aver loss:0.00046 aver reward:-20.20000 explot:0.08916
# global step:76972 episode :81/300 aver loss:0.00043 aver reward:-20.00000 explot:0.08609
# global step:78197 episode :82/300 aver loss:0.00042 aver reward:-20.10000 explot:0.08305
# global step:79655 episode :83/300 aver loss:0.00042 aver reward:-20.00000 explot:0.07958
# global step:80879 episode :84/300 aver loss:0.00041 aver reward:-20.00000 explot:0.07680
# global step:82077 episode :85/300 aver loss:0.00041 aver reward:-20.10000 explot:0.07419
# global step:83081 episode :86/300 aver loss:0.00041 aver reward:-19.90000 explot:0.07207
# global step:84154 episode :87/300 aver loss:0.00042 aver reward:-19.80000 explot:0.06989
# global step:85266 episode :88/300 aver loss:0.00042 aver reward:-19.80000 explot:0.06771
# global step:86482 episode :89/300 aver loss:0.00042 aver reward:-20.00000 explot:0.06542
# global step:87809 episode :90/300 aver loss:0.00043 aver reward:-19.80000 explot:0.06302
# global step:89186 episode :91/300 aver loss:0.00043 aver reward:-19.90000 explot:0.06064
# global step:90597 episode :92/300 aver loss:0.00044 aver reward:-19.70000 explot:0.05832
# global step:91818 episode :93/300 aver loss:0.00044 aver reward:-19.70000 explot:0.05639
# global step:93144 episode :94/300 aver loss:0.00045 aver reward:-19.60000 explot:0.05439
# global step:94739 episode :95/300 aver loss:0.00045 aver reward:-19.60000 explot:0.05209
# global step:96165 episode :96/300 aver loss:0.00045 aver reward:-19.60000 explot:0.05013
# global step:97396 episode :97/300 aver loss:0.00045 aver reward:-19.70000 explot:0.04852
# global step:99224 episode :98/300 aver loss:0.00046 aver reward:-19.50000 explot:0.04624
# global step:100659 episode :99/300 aver loss:0.00046 aver reward:-19.40000 explot:0.04455
# global step:101958 episode :100/300 aver loss:0.00046 aver reward:-19.50000 explot:0.04309
# global step:103529 episode :101/300 aver loss:0.00048 aver reward:-19.40000 explot:0.04140
# global step:105176 episode :102/300 aver loss:0.00048 aver reward:-19.60000 explot:0.03972
# global step:106599 episode :103/300 aver loss:0.00049 aver reward:-19.80000 explot:0.03834
# global step:108531 episode :104/300 aver loss:0.00050 aver reward:-19.40000 explot:0.03658
# global step:110212 episode :105/300 aver loss:0.00051 aver reward:-19.40000 explot:0.03513
# global step:111862 episode :106/300 aver loss:0.00051 aver reward:-19.40000 explot:0.03378
# global step:113951 episode :107/300 aver loss:0.00051 aver reward:-19.30000 explot:0.03218
# global step:115675 episode :108/300 aver loss:0.00052 aver reward:-19.60000 explot:0.03094
# global step:117168 episode :109/300 aver loss:0.00052 aver reward:-19.60000 explot:0.02993
# global step:119158 episode :110/300 aver loss:0.00051 aver reward:-19.40000 explot:0.02865
# global step:121068 episode :111/300 aver loss:0.00050 aver reward:-19.40000 explot:0.02750
# global step:123141 episode :112/300 aver loss:0.00049 aver reward:-19.00000 explot:0.02633
# global step:125612 episode :113/300 aver loss:0.00048 aver reward:-18.70000 explot:0.02504
# global step:127786 episode :114/300 aver loss:0.00047 aver reward:-19.00000 explot:0.02399
# global step:129846 episode :115/300 aver loss:0.00046 aver reward:-18.70000 explot:0.02306
# global step:131591 episode :116/300 aver loss:0.00045 aver reward:-18.70000 explot:0.02232
# global step:133656 episode :117/300 aver loss:0.00044 aver reward:-18.60000 explot:0.02150
# global step:135611 episode :118/300 aver loss:0.00044 aver reward:-18.00000 explot:0.02078
# global step:137076 episode :119/300 aver loss:0.00044 aver reward:-17.90000 explot:0.02026
# global step:138966 episode :120/300 aver loss:0.00044 aver reward:-18.10000 explot:0.01964
# global step:140696 episode :121/300 aver loss:0.00044 aver reward:-18.00000 explot:0.01910
# global step:142737 episode :122/300 aver loss:0.00044 aver reward:-17.90000 explot:0.01850
# global step:144592 episode :123/300 aver loss:0.00044 aver reward:-17.80000 explot:0.01799
# global step:146418 episode :124/300 aver loss:0.00044 aver reward:-17.70000 explot:0.01752
# global step:148373 episode :125/300 aver loss:0.00043 aver reward:-17.80000 explot:0.01704
# global step:150753 episode :126/300 aver loss:0.00043 aver reward:-17.40000 explot:0.01651
# global step:152821 episode :127/300 aver loss:0.00044 aver reward:-17.20000 explot:0.01607
# global step:154842 episode :128/300 aver loss:0.00043 aver reward:-17.50000 explot:0.01568
# global step:157013 episode :129/300 aver loss:0.00043 aver reward:-17.10000 explot:0.01528
# global step:159147 episode :130/300 aver loss:0.00042 aver reward:-17.00000 explot:0.01492
# global step:161477 episode :131/300 aver loss:0.00042 aver reward:-17.00000 explot:0.01455
# global step:163720 episode :132/300 aver loss:0.00041 aver reward:-17.20000 explot:0.01422
# global step:165681 episode :133/300 aver loss:0.00041 aver reward:-17.50000 explot:0.01396
# global step:167496 episode :134/300 aver loss:0.00041 aver reward:-17.40000 explot:0.01372
# global step:169843 episode :135/300 aver loss:0.00041 aver reward:-17.20000 explot:0.01344
# global step:171800 episode :136/300 aver loss:0.00040 aver reward:-17.30000 explot:0.01323
# global step:173765 episode :137/300 aver loss:0.00040 aver reward:-17.30000 explot:0.01302
# global step:175662 episode :138/300 aver loss:0.00039 aver reward:-17.30000 explot:0.01284
# global step:177420 episode :139/300 aver loss:0.00039 aver reward:-17.40000 explot:0.01267
# global step:179283 episode :140/300 aver loss:0.00039 aver reward:-17.50000 explot:0.01251
# global step:181531 episode :141/300 aver loss:0.00039 aver reward:-17.40000 explot:0.01233
# global step:183341 episode :142/300 aver loss:0.00039 aver reward:-17.50000 explot:0.01220
# global step:185297 episode :143/300 aver loss:0.00039 aver reward:-17.40000 explot:0.01206
# global step:187398 episode :144/300 aver loss:0.00039 aver reward:-17.60000 explot:0.01192
# global step:189575 episode :145/300 aver loss:0.00038 aver reward:-17.70000 explot:0.01178
# global step:192071 episode :146/300 aver loss:0.00038 aver reward:-17.20000 explot:0.01164
# global step:194274 episode :147/300 aver loss:0.00038 aver reward:-16.90000 explot:0.01152
# global step:196644 episode :148/300 aver loss:0.00037 aver reward:-16.90000 explot:0.01141
# global step:198640 episode :149/300 aver loss:0.00037 aver reward:-17.00000 explot:0.01132
# global step:201168 episode :150/300 aver loss:0.00036 aver reward:-16.70000 explot:0.01121
# global step:203510 episode :151/300 aver loss:0.00036 aver reward:-16.60000 explot:0.01112
# global step:205500 episode :152/300 aver loss:0.00035 aver reward:-16.50000 explot:0.01105
# global step:207380 episode :153/300 aver loss:0.00035 aver reward:-16.50000 explot:0.01099
# global step:209263 episode :154/300 aver loss:0.00034 aver reward:-16.40000 explot:0.01093
# global step:211443 episode :155/300 aver loss:0.00034 aver reward:-16.40000 explot:0.01086
# global step:213630 episode :156/300 aver loss:0.00033 aver reward:-16.70000 explot:0.01080
# global step:215734 episode :157/300 aver loss:0.00033 aver reward:-17.00000 explot:0.01075
# global step:217606 episode :158/300 aver loss:0.00033 aver reward:-17.10000 explot:0.01070
# global step:219795 episode :159/300 aver loss:0.00034 aver reward:-17.20000 explot:0.01065
# global step:222115 episode :160/300 aver loss:0.00033 aver reward:-17.50000 explot:0.01060
# global step:224328 episode :161/300 aver loss:0.00034 aver reward:-17.80000 explot:0.01056
# global step:226862 episode :162/300 aver loss:0.00034 aver reward:-17.40000 explot:0.01051
# global step:228779 episode :163/300 aver loss:0.00034 aver reward:-17.20000 explot:0.01048
# global step:230603 episode :164/300 aver loss:0.00034 aver reward:-17.40000 explot:0.01045
# global step:232292 episode :165/300 aver loss:0.00035 aver reward:-17.50000 explot:0.01043
# global step:235083 episode :166/300 aver loss:0.00035 aver reward:-17.60000 explot:0.01039
# global step:237403 episode :167/300 aver loss:0.00036 aver reward:-17.40000 explot:0.01036
# global step:239437 episode :168/300 aver loss:0.00036 aver reward:-17.10000 explot:0.01034
# global step:241521 episode :169/300 aver loss:0.00036 aver reward:-17.30000 explot:0.01032
# global step:244342 episode :170/300 aver loss:0.00036 aver reward:-16.90000 explot:0.01029
# global step:246151 episode :171/300 aver loss:0.00035 aver reward:-16.90000 explot:0.01027
# global step:248623 episode :172/300 aver loss:0.00035 aver reward:-17.10000 explot:0.01025
# global step:250776 episode :173/300 aver loss:0.00036 aver reward:-17.30000 explot:0.01023
# global step:252892 episode :174/300 aver loss:0.00036 aver reward:-17.10000 explot:0.01022
# global step:255370 episode :175/300 aver loss:0.00036 aver reward:-17.00000 explot:0.01020
# global step:258456 episode :176/300 aver loss:0.00036 aver reward:-16.80000 explot:0.01018
# global step:260968 episode :177/300 aver loss:0.00036 aver reward:-17.10000 explot:0.01017
# global step:263284 episode :178/300 aver loss:0.00036 aver reward:-17.30000 explot:0.01015
# global step:265349 episode :179/300 aver loss:0.00035 aver reward:-17.10000 explot:0.01014
# global step:267743 episode :180/300 aver loss:0.00035 aver reward:-17.10000 explot:0.01013
# global step:270027 episode :181/300 aver loss:0.00036 aver reward:-16.60000 explot:0.01012
# global step:272095 episode :182/300 aver loss:0.00036 aver reward:-17.00000 explot:0.01011
# global step:273366 episode :183/300 aver loss:0.00036 aver reward:-17.20000 explot:0.01011
# global step:275264 episode :184/300 aver loss:0.00036 aver reward:-17.30000 explot:0.01010
# global step:276827 episode :185/300 aver loss:0.00036 aver reward:-17.50000 explot:0.01010
# global step:278969 episode :186/300 aver loss:0.00035 aver reward:-18.00000 explot:0.01009
# global step:281842 episode :187/300 aver loss:0.00035 aver reward:-17.20000 explot:0.01008
# global step:284059 episode :188/300 aver loss:0.00035 aver reward:-17.10000 explot:0.01008
# global step:286004 episode :189/300 aver loss:0.00035 aver reward:-17.10000 explot:0.01007
# global step:288169 episode :190/300 aver loss:0.00035 aver reward:-17.30000 explot:0.01007
# global step:290503 episode :191/300 aver loss:0.00034 aver reward:-17.60000 explot:0.01006
# global step:292844 episode :192/300 aver loss:0.00034 aver reward:-17.30000 explot:0.01006
# global step:294794 episode :193/300 aver loss:0.00033 aver reward:-16.90000 explot:0.01005
# global step:295991 episode :194/300 aver loss:0.00032 aver reward:-17.00000 explot:0.01005
# global step:297510 episode :195/300 aver loss:0.00032 aver reward:-17.10000 explot:0.01005
# global step:299817 episode :196/300 aver loss:0.00031 aver reward:-16.70000 explot:0.01005
# global step:301962 episode :197/300 aver loss:0.00031 aver reward:-17.40000 explot:0.01004
# global step:303970 episode :198/300 aver loss:0.00030 aver reward:-17.20000 explot:0.01004
# global step:306160 episode :199/300 aver loss:0.00030 aver reward:-17.10000 explot:0.01004
# global step:308311 episode :200/300 aver loss:0.00030 aver reward:-16.90000 explot:0.01003
# global step:310297 episode :201/300 aver loss:0.00029 aver reward:-17.20000 explot:0.01003
# global step:312877 episode :202/300 aver loss:0.00029 aver reward:-17.30000 explot:0.01003
# global step:314806 episode :203/300 aver loss:0.00029 aver reward:-17.70000 explot:0.01003
# global step:316525 episode :204/300 aver loss:0.00029 aver reward:-17.70000 explot:0.01003
# global step:318365 episode :205/300 aver loss:0.00029 aver reward:-17.40000 explot:0.01002
# global step:320322 episode :206/300 aver loss:0.00030 aver reward:-17.80000 explot:0.01002
# global step:322133 episode :207/300 aver loss:0.00030 aver reward:-17.90000 explot:0.01002
# global step:323600 episode :208/300 aver loss:0.00030 aver reward:-18.50000 explot:0.01002
# global step:325036 episode :209/300 aver loss:0.00030 aver reward:-18.60000 explot:0.01002
# global step:326996 episode :210/300 aver loss:0.00030 aver reward:-19.00000 explot:0.01002
# global step:328921 episode :211/300 aver loss:0.00030 aver reward:-18.80000 explot:0.01002
# global step:331000 episode :212/300 aver loss:0.00030 aver reward:-18.70000 explot:0.01002
# global step:332920 episode :213/300 aver loss:0.00030 aver reward:-18.40000 explot:0.01002
# global step:334872 episode :214/300 aver loss:0.00030 aver reward:-18.30000 explot:0.01001
# global step:337557 episode :215/300 aver loss:0.00030 aver reward:-18.00000 explot:0.01001
# global step:340070 episode :216/300 aver loss:0.00030 aver reward:-17.70000 explot:0.01001
# global step:341782 episode :217/300 aver loss:0.00030 aver reward:-17.70000 explot:0.01001
# global step:343500 episode :218/300 aver loss:0.00030 aver reward:-17.60000 explot:0.01001
# global step:345939 episode :219/300 aver loss:0.00031 aver reward:-17.50000 explot:0.01001
# global step:348193 episode :220/300 aver loss:0.00032 aver reward:-17.20000 explot:0.01001
# global step:350965 episode :221/300 aver loss:0.00031 aver reward:-16.50000 explot:0.01001
# global step:353325 episode :222/300 aver loss:0.00032 aver reward:-16.30000 explot:0.01001
# global step:355208 episode :223/300 aver loss:0.00032 aver reward:-16.30000 explot:0.01001
# global step:356976 episode :224/300 aver loss:0.00031 aver reward:-16.20000 explot:0.01001
# global step:359130 episode :225/300 aver loss:0.00031 aver reward:-16.50000 explot:0.01001
# global step:361171 episode :226/300 aver loss:0.00031 aver reward:-17.00000 explot:0.01001
# global step:363602 episode :227/300 aver loss:0.00031 aver reward:-16.90000 explot:0.01001
# global step:365816 episode :228/300 aver loss:0.00032 aver reward:-16.60000 explot:0.01001
# global step:367806 episode :229/300 aver loss:0.00031 aver reward:-16.70000 explot:0.01000
# global step:370158 episode :230/300 aver loss:0.00030 aver reward:-17.00000 explot:0.01000
# global step:373105 episode :231/300 aver loss:0.00030 aver reward:-17.00000 explot:0.01000
# global step:375597 episode :232/300 aver loss:0.00030 aver reward:-16.70000 explot:0.01000
# global step:377975 episode :233/300 aver loss:0.00030 aver reward:-16.60000 explot:0.01000
# global step:380274 episode :234/300 aver loss:0.00029 aver reward:-16.80000 explot:0.01000
# global step:382412 episode :235/300 aver loss:0.00029 aver reward:-17.00000 explot:0.01000
# global step:384032 episode :236/300 aver loss:0.00029 aver reward:-16.90000 explot:0.01000
# global step:386344 episode :237/300 aver loss:0.00028 aver reward:-17.10000 explot:0.01000
# global step:389120 episode :238/300 aver loss:0.00027 aver reward:-16.70000 explot:0.01000
# global step:391269 episode :239/300 aver loss:0.00027 aver reward:-16.90000 explot:0.01000
# global step:394112 episode :240/300 aver loss:0.00027 aver reward:-16.60000 explot:0.01000
# global step:396435 episode :241/300 aver loss:0.00027 aver reward:-17.40000 explot:0.01000
# global step:398713 episode :242/300 aver loss:0.00027 aver reward:-17.90000 explot:0.01000
# global step:400806 episode :243/300 aver loss:0.00027 aver reward:-18.00000 explot:0.01000
# global step:402801 episode :244/300 aver loss:0.00027 aver reward:-17.70000 explot:0.01000
# global step:405321 episode :245/300 aver loss:0.00027 aver reward:-17.60000 explot:0.01000
# global step:408393 episode :246/300 aver loss:0.00028 aver reward:-17.00000 explot:0.01000
# global step:410933 episode :247/300 aver loss:0.00028 aver reward:-16.80000 explot:0.01000
# global step:413059 episode :248/300 aver loss:0.00028 aver reward:-17.10000 explot:0.01000
# global step:415515 episode :249/300 aver loss:0.00028 aver reward:-16.80000 explot:0.01000
# global step:417720 episode :250/300 aver loss:0.00027 aver reward:-17.00000 explot:0.01000
# global step:419706 episode :251/300 aver loss:0.00027 aver reward:-17.10000 explot:0.01000
# global step:422171 episode :252/300 aver loss:0.00027 aver reward:-17.10000 explot:0.01000
# global step:424267 episode :253/300 aver loss:0.00027 aver reward:-17.00000 explot:0.01000
# global step:427355 episode :254/300 aver loss:0.00027 aver reward:-16.60000 explot:0.01000
# global step:429725 episode :255/300 aver loss:0.00027 aver reward:-16.50000 explot:0.01000
# global step:431943 episode :256/300 aver loss:0.00026 aver reward:-17.10000 explot:0.01000
# global step:434984 episode :257/300 aver loss:0.00026 aver reward:-16.30000 explot:0.01000
# global step:437974 episode :258/300 aver loss:0.00026 aver reward:-16.00000 explot:0.01000
# global step:440786 episode :259/300 aver loss:0.00026 aver reward:-15.60000 explot:0.01000
# global step:443425 episode :260/300 aver loss:0.00026 aver reward:-15.20000 explot:0.01000
# global step:445865 episode :261/300 aver loss:0.00027 aver reward:-14.80000 explot:0.01000
# global step:448247 episode :262/300 aver loss:0.00027 aver reward:-14.30000 explot:0.01000
# global step:450222 episode :263/300 aver loss:0.00027 aver reward:-14.50000 explot:0.01000
# global step:452550 episode :264/300 aver loss:0.00028 aver reward:-14.70000 explot:0.01000
# global step:454736 episode :265/300 aver loss:0.00028 aver reward:-15.00000 explot:0.01000
# global step:456576 episode :266/300 aver loss:0.00028 aver reward:-14.60000 explot:0.01000
# global step:458587 episode :267/300 aver loss:0.00028 aver reward:-15.70000 explot:0.01000
# global step:460558 episode :268/300 aver loss:0.00027 aver reward:-16.30000 explot:0.01000
# global step:463618 episode :269/300 aver loss:0.00027 aver reward:-16.70000 explot:0.01000
# global step:465156 episode :270/300 aver loss:0.00027 aver reward:-17.30000 explot:0.01000
# global step:467203 episode :271/300 aver loss:0.00027 aver reward:-17.50000 explot:0.01000
# global step:469670 episode :272/300 aver loss:0.00026 aver reward:-17.70000 explot:0.01000
# global step:471725 episode :273/300 aver loss:0.00025 aver reward:-17.70000 explot:0.01000
# global step:474499 episode :274/300 aver loss:0.00025 aver reward:-17.50000 explot:0.01000
# global step:477148 episode :275/300 aver loss:0.00024 aver reward:-17.10000 explot:0.01000
# global step:479709 episode :276/300 aver loss:0.00024 aver reward:-17.20000 explot:0.01000
# global step:481352 episode :277/300 aver loss:0.00024 aver reward:-17.10000 explot:0.01000
# global step:483385 episode :278/300 aver loss:0.00024 aver reward:-17.10000 explot:0.01000
# global step:486092 episode :279/300 aver loss:0.00024 aver reward:-16.70000 explot:0.01000
# global step:487834 episode :280/300 aver loss:0.00024 aver reward:-16.60000 explot:0.01000
# global step:489802 episode :281/300 aver loss:0.00024 aver reward:-16.70000 explot:0.01000
# global step:492591 episode :282/300 aver loss:0.00024 aver reward:-16.20000 explot:0.01000
# global step:495212 episode :283/300 aver loss:0.00024 aver reward:-15.60000 explot:0.01000
# global step:497856 episode :284/300 aver loss:0.00025 aver reward:-15.70000 explot:0.01000
# global step:500811 episode :285/300 aver loss:0.00025 aver reward:-14.80000 explot:0.01000
# global step:503081 episode :286/300 aver loss:0.00026 aver reward:-14.70000 explot:0.01000
# global step:506028 episode :287/300 aver loss:0.00026 aver reward:-14.20000 explot:0.01000
# global step:508090 episode :288/300 aver loss:0.00026 aver reward:-14.10000 explot:0.01000
# global step:510542 episode :289/300 aver loss:0.00027 aver reward:-14.60000 explot:0.01000
# global step:512963 episode :290/300 aver loss:0.00027 aver reward:-14.30000 explot:0.01000
# global step:515030 episode :291/300 aver loss:0.00026 aver reward:-14.10000 explot:0.01000
# global step:517041 episode :292/300 aver loss:0.00026 aver reward:-15.00000 explot:0.01000
# global step:519040 episode :293/300 aver loss:0.00027 aver reward:-15.20000 explot:0.01000
# global step:520724 episode :294/300 aver loss:0.00027 aver reward:-15.90000 explot:0.01000
# global step:523092 episode :295/300 aver loss:0.00028 aver reward:-16.50000 explot:0.01000
# global step:524980 episode :296/300 aver loss:0.00028 aver reward:-16.90000 explot:0.01000
# global step:527499 episode :297/300 aver loss:0.00028 aver reward:-16.90000 explot:0.01000
# global step:529897 episode :298/300 aver loss:0.00029 aver reward:-16.80000 explot:0.01000
# global step:533006 episode :299/300 aver loss:0.00029 aver reward:-16.10000 explot:0.01000

# %%
# plot loss and rewards
import matplotlib.pyplot as plt
def plot_(losses, rewards):
    plt.figure()
    plt.title('rewards')
    plt.plot(list(range(len(rewards))), rewards)
    
    plt.figure()
    plt.title('loss')
    plt.plot(list(range(len(losses))),losses)
    plt.show()

plot_(losses, rewards)
