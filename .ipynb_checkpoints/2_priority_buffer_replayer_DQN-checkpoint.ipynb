# %% [markdown]
# ## DQN base on priority buffer replayer
#
# ### discussion
# #### 1
# 在进行训练的时候，开始使用的是adam优化器，发现收敛的特别慢，训练1000个episodes还没有收敛。然而使用RMSprop 优化器就可以很快的收敛。暂时不知道为什么会产生这种现象。
# #### 2
# loss = F.smooth_l1_loss(eval_q, tar_q)
#
# loss = torch.mean(isweights*(eval_q - tar_q)**2)
#
# 使用第一个作为td_loss时收敛比较快，使用第二个时收敛速度明显降低
#
# 使用第二个td_loss时reward和loss曲线如下：
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
#
# ### reference:
#        https://www.cnblogs.com/pinard/p/9797695.html
#
#        https://zhuanlan.zhihu.com/p/47578210

# %%
import numpy as np
import torch
from torch import nn, optim
import os
import matplotlib.pyplot as plt
from atari_wrappers import make_atari, wrap_deepmind,LazyFrames

# %%
# preprocess
def prepro(obs):
    """
    preprocess observation 
    [84,84,4]=>[4,84,84]
    """
    obs = obs._force().transpose(2,0,1)/255  # 0-255 => 0-1, [84,84,4] => [4,84,84]
    return obs

# %%
# net
import torch
from torch import nn
class Net(nn.Module):
    """
    Initialize a deep Q-learning network as described in
    https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
    Arguments:
        in_channels: number of channel of input.
            i.e The number of most recent frames stacked together as describe in the paper
        out_num: number of action-value to output, one-to-one correspondence to action in game.
    """
    def __init__(self, in_channel=4, out_num=6):
        super(Net,self).__init__()
        # layer setting paramters
        layers = [32,64,64]
        # output_size = (input_size-kernel_size)/stride + 1
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channel,layers[0],kernel_size=8,stride=4), # [batch,4,84,84]=>[batch,layers[0],20,20] 
            nn.ReLU(),
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(layers[0],layers[1],kernel_size=4,stride=2), # [batch,layers[0],20,20]=>[batch,layers[1],9,9]
            nn.ReLU(),
        )
        self.conv3 = nn.Sequential(
            nn.Conv2d(layers[1],layers[2],kernel_size=3,stride=1), # [batch,layers[1],9,9]=>[batch,layers[2],7,7]
            nn.ReLU(),
        )
        self.linear1 = nn.Sequential(
            nn.Linear(7*7*layers[2], 512),
            nn.ReLU()
        )
        self.linear2 = nn.Linear(512, out_num)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # flatten
        x = x.reshape(x.size(0), -1)  # [batch, layers[2],7,7]=>[batch,layers[2]*7*7]
        x = self.linear1(x)
        y = self.linear2(x)
        # y = F.softmax(y)  # turn to probability
        return y
pre_net = Net()
print(pre_net)
# Out:
# Net(
#   (conv1): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#   )
#   (linear1): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#   )
#   (linear2): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
class SumTree():
    data_point = 0  # data idx
    def __init__(self, capacity):
        self.capacity = capacity  # num of leaves
        self.tree = np.zeros(capacity*2-1)
        self.transition = np.zeros(capacity, dtype=object) # save data
        self.n_entries = 0
        
    def total_p(self):
        return self.tree[0]  # return the 0 node
        
    def add(self, p, data):
        # add data and priority
        # p: priority, data 
        idx = self.data_point + self.capacity -1
        self.transition[self.data_point] = data   # save data        
        self.data_point += 1
        if self.data_point >= self.capacity:
            self.data_point = 0            
        
        change = p - self.tree[idx]   
        self.tree[idx] = p            # save priority
        self.n_entries += 1   # count num of entries
        
        # propagation  update parents nodes
        p_idx = (idx-1)//2  # parent idx
        while True:           
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def update(self,idx, p):
        # update tree
        change = p - self.tree[idx]
        self.tree[idx] = p  # change priority in leaves node        
        # update parents node
        p_idx = (idx-1)//2   #
        while True:            
            self.tree[p_idx] += change
            if p_idx != 0:
                p_idx = (p_idx-1)//2
            else:
                break
    
    def retrieve(self, p_idx, s):
        # search leaf idx for s        
        while True:
            l_idx = p_idx*2 + 1  # left child idx
            r_idx = l_idx +1     # right child idx  
            if l_idx >= self.capacity*2-1: # 其子节点超出，结点序号范围， 说明已经是叶子结点
                return p_idx 
            if self.tree[l_idx] >= s:
                p_idx = l_idx
            else:
                p_idx = r_idx
                s -= self.tree[l_idx]
            
    def get(self, s):
        # get a data and priority from tree and transition        
        # get idx of leaves
        idx = self.retrieve(0,s)
        priority = self.tree[idx]
        data_idx = idx - (self.capacity - 1)
        data = self.transition[data_idx]
        return idx, priority, data

# %%
# memory buffer replay
class Memory_buffer_replay():
    beta = 0.4
    beta_increment_per_sampling = 0.001
    abs_err_upper = 1.
    def __init__(self, capacity, device):
        self.capacity = capacity
        self.sumtree = SumTree(self.capacity)
        self.device = device
        
        self.e = 0.01
        self.a = 0.6
        self.prio_max = 0.1
        
    def store_record(self, state, state_next, a, r, done):
        data = (state, state_next, a, r, done)
        priority = (np.abs(self.prio_max) + self.e) ** self.a #  proportional priority
        self.sumtree.add(priority, data) # save p, data in sumtree
        
    def sample(self, batchsz):
        states, state_nexts, a_s, r_s, done_s = [],[],[],[],[]
        idxs, ps, isweights = [],[],[]  # idss, prioritys
        segment = self.sumtree.total_p()/batchsz
        
        self.beta = np.min([1., self.beta+self.beta_increment_per_sampling])
        min_prob = np.min(self.sumtree.tree[-self.capacity:])/self.sumtree.total_p()
        
        for i in range(batchsz):
            down_bound = i*segment
            up_bound = (i+1)*segment
            s = np.random.uniform(down_bound, up_bound)
            idx, p, data = self.sumtree.get(s) 
            
            state, state_next, a, r, done = data
            prob = p/self.sumtree.total_p()
            isweight = np.power(prob/min_prob, -self.beta)
            
            isweights.append(isweight)
            idxs.append(idx)
            ps.append(p)
            states.append(state)
            state_nexts.append(state_next)
            a_s.append(a)
            r_s.append(r)
            done_s.append(done)
        
        #from list to numpy
#         idxs, ps = np.array(idxs), np.array(ps)
        # function: list=> tensor
        list2tensor = lambda data: torch.from_numpy(np.array(data)).to(self.device)
        
        isweights = list2tensor(isweights)
        states, state_nexts = list2tensor(states), list2tensor(state_nexts)
        a_s, r_s, done_s = list2tensor(a_s), list2tensor(r_s), list2tensor(done_s)
        # isweights: tensor, idx:list, ps:list, states:tensor, as, rs, done_s:tensor
        return isweights, idxs, ps, states, state_nexts, a_s, r_s, done_s
    
    def update(self, idxs, errors):
        # update data priority
        self.prio_max = max(self.prio_max, max(np.abs(errors)))
        for i, idx in enumerate(idxs):
            p = (np.abs(errors[i]) + self.e) ** self.a
            self.sumtree.update(idx, p)

# %%
# DQN with priority
import torch.nn.functional as F
class DQN_priority():
    def __init__(self, args, env, load_model=False):        
        # use cuda
        cuda = True
        if cuda:
            self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        else:
            self.device = torch.device('cpu')
            
        # env
        self.env = env
        self.n_actions = env.action_space.n
        self.dim_shape = env.observation_space.shape
        
        # hyperparams
        self.capacity = 100000
        self.decay = 0.99
        self.episodes = args.episodes
        self.log_interval = args.log_interval  # print state per log_interval epsisode
        self.save_interval = args.save_interval  # interval for save model 
        
        self.epilon_max = 1
        self.epilon_min = 0.01
        self.learning_start = 10000  # 装满10000 再开始
        self.epilon_decay = 30000
        
        # learn params
        self.lr = args.lr
        self.batchsz = args.batchsz
        self.iter =0
        self.iter_max = args.iter_max
        
        # build model
        self.eval_model = Net().to(self.device)
        self.tar_model = Net().to(self.device)  
        # load model
        if load_model:
            self.eval_model.load_state_dict(torch.load('dqn_priority.mdl'))
        self.tar_model.load_state_dict(self.eval_model.state_dict())
        # build optimizer
        self.optimizer = optim.RMSprop(self.eval_model.parameters(),lr=self.lr, eps=0.001, alpha=0.95)
#         self.optimizer = optim.Adam(self.eval_model.parameters(), self.lr)
#         self.cost_F = nn.MSELoss()
        
        # build memory buffer
        self.buffer = Memory_buffer_replay(self.capacity, self.device)
    
    def train(self):
        episodes = self.episodes
        losses = []
        rewards  = []
        
        # decay function explot ratio
        epilon_by_g_step = lambda step_idx:self.epilon_min + (self.epilon_max-self.epilon_min)*np.exp(-1*step_idx/self.epilon_decay)
        # global step
        global_step = 0
        
        for epis in range(episodes):
            state = self.env.reset()
            state = prepro(state) # [84,84,4]=>[4,84,84]
            reward_sum = 0
            loss_ = []
            # decay explot ratio
#             self.explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/50.)
            while True:
                # decay explot ratio
                epsilon = epilon_by_g_step(global_step)
                global_step += 1 
                act = self.make_action(state, epsilon) # choose action
                state_next, r, done, inf = self.env.step(act)
                state_next = prepro(state_next)
                reward_sum += r                
                # store data
                self.buffer.store_record(state, state_next, act, r, done)                
                if done:                    
                    rewards.append(reward_sum)
                    losses.append(np.mean(loss_))
                    break  # start another episode
                else:
                    state = state_next
            
                # learn model
                if self.buffer.sumtree.n_entries == self.learning_start:
                    print('#'*30 + 'start learning' + '#'*30)
                if self.buffer.sumtree.n_entries > self.learning_start:
                    loss = self.learn()
                    loss_.append(loss)
                else:
                    loss_.append(0)
                
            # print train state
            if epis%self.log_interval==0 and epis>0:
                #print(losses)
                print('global step:{}'.format(global_step-1),
                      'episode :{}/{}'.format(epis, self.episodes), 
                      'aver loss:{:.5f}'.format(np.mean(losses[-10:])), 
                      'aver reward:{:.5f}'.format(np.mean(rewards[-10:])),
                      'explot:{:.5f}'.format(epsilon)
                     )
            # save model
            if epis%self.save_interval==0 and epis>0:
                torch.save(self.eval_model.state_dict(),'dqn_priority.mdl')
        return losses, rewards
    
    def learn(self):
        # learn the model
        
        # get data,  idxs, ps : list. others tensor
        isweights, idxs, ps, state, state_next, act_s, r_s, done_s = self.buffer.sample(self.batchsz)        
        
        # pre
        eval_q = self.eval_model(state.float()).gather(1,act_s.unsqueeze(1).long())  # get pre and choose Q with act_c,[batch,1]
        eval_q = eval_q.squeeze(-1)  # [batch,1] => [batch]
        # compute label
        next_q = self.tar_model(state_next.float()).detach() # not update so use detach
        next_max_q = next_q.max(1)[0] # torch.max() return [max_data, max_idx]
        decay = torch.tensor(self.decay).float().to(self.device)
        tar_q = r_s.float() + decay*next_max_q
        tar_q = torch.where(done_s>0, r_s.float(), tar_q)  # Q_next = r when done is true
        
        #compute td-loss
        loss = F.smooth_l1_loss(eval_q, tar_q)
#         loss = torch.mean(isweights*(eval_q - tar_q)**2) # loss expect input dim=[batch,1]
        # update buffer with error
        errors = (eval_q - tar_q).detach().cpu().tolist()
        self.buffer.update(idxs, errors)
        
        self.optimizer.zero_grad()
        loss.backward()
        # clip gradient
        for param in self.eval_model.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
        
        # update tar_model
        self.iter += 1
        if self.iter%self.iter_max==0:
            self.tar_model.load_state_dict(self.eval_model.state_dict())
        
        return loss.cpu().item() # ruturn mean loss
    
    def make_action(self, state, epsilon=None):
        state = torch.from_numpy(state).float()
        
        pre_q = self.eval_model(state.unsqueeze(0).to(self.device))
        pre_q = pre_q.cpu().detach()
        
        #explot_ep = self.explot_ep_min + (self.explot_ep_max-self.explot_ep_min)*np.exp(-1*epis/20.)
        if epsilon==None:
            epsilon=self.epsion_min
        if np.random.uniform()< epsilon:
            action = np.random.choice(self.n_actions) # random choose action
        else:
            action = torch.argmax(pre_q)
            action = action.item()
        return action

# %%
# argument
class Argument():
    def __init__(self):
        self.lr = 1e-3
        self.batchsz = 32
        
        self.episodes = 210
        
        self.log_interval = 1 # print state per log_interval epsisode
        self.save_interval = 20  # interval for save model
        
        self.iter_max = 1000  # update tar_model interval

args = Argument()

# %%
# main
import gym
env = make_atari('PongNoFrameskip-v4') # only use in no frameskip environment
env = wrap_deepmind(env, scale = False, frame_stack=True )

load_model = False
run_dqn = DQN_priority(args, env, load_model)
losses, rewards = run_dqn.train()
# Out:
# global step:1859 episode :1/210 aver loss:0.00000 aver reward:-20.00000 explot:0.94052
# global step:2821 episode :2/210 aver loss:0.00000 aver reward:-20.00000 explot:0.91115
# global step:3669 episode :3/210 aver loss:0.00000 aver reward:-20.25000 explot:0.88603
# global step:4556 episode :4/210 aver loss:0.00000 aver reward:-20.40000 explot:0.86051
# global step:5530 episode :5/210 aver loss:0.00000 aver reward:-20.16667 explot:0.83334
# global step:6565 episode :6/210 aver loss:0.00000 aver reward:-20.28571 explot:0.80542
# global step:7535 episode :7/210 aver loss:0.00000 aver reward:-20.25000 explot:0.78011
# global step:8444 episode :8/210 aver loss:0.00000 aver reward:-20.33333 explot:0.75713
# global step:9375 episode :9/210 aver loss:0.00000 aver reward:-20.20000 explot:0.73430
# ##############################start learning##############################
# /home/ryzen/anaconda3/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in double_scalars
# global step:10440 episode :10/210 aver loss:0.00000 aver reward:-20.00000 explot:0.70904
# global step:11363 episode :11/210 aver loss:0.00000 aver reward:-20.10000 explot:0.68786
# global step:12356 episode :12/210 aver loss:0.00000 aver reward:-20.00000 explot:0.66579
# global step:13220 episode :13/210 aver loss:0.00000 aver reward:-20.00000 explot:0.64717
# global step:14065 episode :14/210 aver loss:0.00000 aver reward:-20.00000 explot:0.62947
# global step:14961 episode :15/210 aver loss:0.00000 aver reward:-20.10000 explot:0.61125
# global step:15943 episode :16/210 aver loss:0.00000 aver reward:-20.00000 explot:0.59188
# global step:16866 episode :17/210 aver loss:0.00000 aver reward:-20.00000 explot:0.57425
# global step:17756 episode :18/210 aver loss:0.00000 aver reward:-19.90000 explot:0.55776
# global step:18685 episode :19/210 aver loss:0.00000 aver reward:-19.90000 explot:0.54106
# global step:19475 episode :20/210 aver loss:0.00000 aver reward:-20.10000 explot:0.52726
# global step:20513 episode :21/210 aver loss:0.00000 aver reward:-20.00000 explot:0.50967
# global step:21415 episode :22/210 aver loss:0.00000 aver reward:-20.10000 explot:0.49487
# global step:22232 episode :23/210 aver loss:0.00000 aver reward:-20.10000 explot:0.48184
# global step:23068 episode :24/210 aver loss:0.00000 aver reward:-20.10000 explot:0.46887
# global step:23976 episode :25/210 aver loss:0.00000 aver reward:-20.10000 explot:0.45519
# global step:24849 episode :26/210 aver loss:0.00000 aver reward:-20.20000 explot:0.44242
# global step:25608 episode :27/210 aver loss:0.00000 aver reward:-20.30000 explot:0.43162
# global step:26458 episode :28/210 aver loss:0.00000 aver reward:-20.40000 explot:0.41984
# global step:27243 episode :29/210 aver loss:0.00000 aver reward:-20.60000 explot:0.40926
# global step:28088 episode :30/210 aver loss:0.00000 aver reward:-20.60000 explot:0.39817
# global step:28968 episode :31/210 aver loss:0.00000 aver reward:-20.80000 explot:0.38695
# global step:29835 episode :32/210 aver loss:0.00000 aver reward:-20.80000 explot:0.37621
# global step:30752 episode :33/210 aver loss:0.00000 aver reward:-20.60000 explot:0.36518
# global step:31565 episode :34/210 aver loss:0.00000 aver reward:-20.60000 explot:0.35569
# global step:32460 episode :35/210 aver loss:0.00000 aver reward:-20.60000 explot:0.34553
# global step:33342 episode :36/210 aver loss:0.00000 aver reward:-20.60000 explot:0.33581
# global step:34160 episode :37/210 aver loss:0.00000 aver reward:-20.60000 explot:0.32704
# global step:35023 episode :38/210 aver loss:0.00000 aver reward:-20.50000 explot:0.31805
# global step:35812 episode :39/210 aver loss:0.00000 aver reward:-20.50000 explot:0.31006
# global step:36570 episode :40/210 aver loss:0.00000 aver reward:-20.50000 explot:0.30257
# global step:37354 episode :41/210 aver loss:0.00000 aver reward:-20.50000 explot:0.29502
# global step:38291 episode :42/210 aver loss:0.00000 aver reward:-20.60000 explot:0.28626
# global step:39129 episode :43/210 aver loss:0.00000 aver reward:-20.70000 explot:0.27865
# global step:40067 episode :44/210 aver loss:0.00000 aver reward:-20.60000 explot:0.27038
# global step:40933 episode :45/210 aver loss:0.00000 aver reward:-20.60000 explot:0.26297
# global step:41767 episode :46/210 aver loss:0.00000 aver reward:-20.50000 explot:0.25603
# global step:42748 episode :47/210 aver loss:0.00000 aver reward:-20.40000 explot:0.24812
# global step:43592 episode :48/210 aver loss:0.00000 aver reward:-20.50000 explot:0.24151
# global step:44403 episode :49/210 aver loss:0.00000 aver reward:-20.50000 explot:0.23534
# global step:45248 episode :50/210 aver loss:0.00000 aver reward:-20.50000 explot:0.22908
# global step:46006 episode :51/210 aver loss:0.00000 aver reward:-20.50000 explot:0.22361
# global step:46764 episode :52/210 aver loss:0.00000 aver reward:-20.50000 explot:0.21828
# global step:47522 episode :53/210 aver loss:0.00000 aver reward:-20.60000 explot:0.21309
# global step:48279 episode :54/210 aver loss:0.00000 aver reward:-20.70000 explot:0.20803
# global step:49094 episode :55/210 aver loss:0.00000 aver reward:-20.80000 explot:0.20272
# global step:49853 episode :56/210 aver loss:0.00000 aver reward:-20.90000 explot:0.19791
# global step:50793 episode :57/210 aver loss:0.00000 aver reward:-20.80000 explot:0.19211
# global step:51552 episode :58/210 aver loss:0.00000 aver reward:-20.80000 explot:0.18756
# global step:52387 episode :59/210 aver loss:0.00000 aver reward:-20.70000 explot:0.18269
# global step:53220 episode :60/210 aver loss:0.00000 aver reward:-20.60000 explot:0.17796
# global step:54036 episode :61/210 aver loss:0.00000 aver reward:-20.60000 explot:0.17345
# global step:54903 episode :62/210 aver loss:0.00000 aver reward:-20.50000 explot:0.16879
# global step:55690 episode :63/210 aver loss:0.00000 aver reward:-20.50000 explot:0.16468
# global step:56530 episode :64/210 aver loss:0.00000 aver reward:-20.40000 explot:0.16041
# global step:57287 episode :65/210 aver loss:0.00000 aver reward:-20.40000 explot:0.15666
# global step:58049 episode :66/210 aver loss:0.00000 aver reward:-20.40000 explot:0.15298
# global step:58810 episode :67/210 aver loss:0.00000 aver reward:-20.60000 explot:0.14940
# global step:59703 episode :68/210 aver loss:0.00000 aver reward:-20.50000 explot:0.14531
# global step:60566 episode :69/210 aver loss:0.00000 aver reward:-20.50000 explot:0.14148
# global step:61382 episode :70/210 aver loss:0.00000 aver reward:-20.60000 explot:0.13795
# global step:62199 episode :71/210 aver loss:0.00000 aver reward:-20.60000 explot:0.13451
# global step:62988 episode :72/210 aver loss:0.00000 aver reward:-20.70000 explot:0.13128
# global step:63747 episode :73/210 aver loss:0.00000 aver reward:-20.70000 explot:0.12825
# global step:64507 episode :74/210 aver loss:0.00000 aver reward:-20.80000 explot:0.12529
# global step:65402 episode :75/210 aver loss:0.00000 aver reward:-20.70000 explot:0.12190
# global step:66176 episode :76/210 aver loss:0.00000 aver reward:-20.70000 explot:0.11905
# global step:67016 episode :77/210 aver loss:0.00000 aver reward:-20.70000 explot:0.11604
# global step:67910 episode :78/210 aver loss:0.00000 aver reward:-20.70000 explot:0.11293
# global step:68774 episode :79/210 aver loss:0.00000 aver reward:-20.70000 explot:0.11001
# global step:69535 episode :80/210 aver loss:0.00000 aver reward:-20.70000 explot:0.10750
# global step:70324 episode :81/210 aver loss:0.00000 aver reward:-20.70000 explot:0.10497
# global step:71109 episode :82/210 aver loss:0.00000 aver reward:-20.70000 explot:0.10252
# global step:71871 episode :83/210 aver loss:0.00000 aver reward:-20.70000 explot:0.10020
# global step:72661 episode :84/210 aver loss:0.00000 aver reward:-20.70000 explot:0.09785
# global step:73416 episode :85/210 aver loss:0.00000 aver reward:-20.80000 explot:0.09567
# global step:74172 episode :86/210 aver loss:0.00000 aver reward:-20.80000 explot:0.09354
# global step:75008 episode :87/210 aver loss:0.00000 aver reward:-20.70000 explot:0.09124
# global step:75765 episode :88/210 aver loss:0.00000 aver reward:-20.80000 explot:0.08922
# global step:76578 episode :89/210 aver loss:0.00000 aver reward:-20.90000 explot:0.08710
# global step:77337 episode :90/210 aver loss:0.00000 aver reward:-20.90000 explot:0.08517
# global step:78120 episode :91/210 aver loss:0.00000 aver reward:-20.90000 explot:0.08324
# global step:78881 episode :92/210 aver loss:0.00000 aver reward:-20.90000 explot:0.08140
# global step:79643 episode :93/210 aver loss:0.00000 aver reward:-20.90000 explot:0.07961
# global step:80398 episode :94/210 aver loss:0.00000 aver reward:-20.90000 explot:0.07788
# global step:81186 episode :95/210 aver loss:0.00000 aver reward:-20.90000 explot:0.07612
# global step:81972 episode :96/210 aver loss:0.00000 aver reward:-20.90000 explot:0.07441
# global step:82733 episode :97/210 aver loss:0.00000 aver reward:-21.00000 explot:0.07280
# global step:83517 episode :98/210 aver loss:0.00000 aver reward:-21.00000 explot:0.07118
# global step:84272 episode :99/210 aver loss:0.00000 aver reward:-21.00000 explot:0.06966
# global step:85028 episode :100/210 aver loss:0.00000 aver reward:-21.00000 explot:0.06817
# global step:85785 episode :101/210 aver loss:0.00000 aver reward:-21.00000 explot:0.06672
# global step:86651 episode :102/210 aver loss:0.00000 aver reward:-20.90000 explot:0.06511
# global step:87725 episode :103/210 aver loss:0.00000 aver reward:-20.50000 explot:0.06317
# global step:88560 episode :104/210 aver loss:0.00000 aver reward:-20.40000 explot:0.06171
# global step:89316 episode :105/210 aver loss:0.00000 aver reward:-20.40000 explot:0.06043
# global step:90075 episode :106/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05917
# global step:90832 episode :107/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05794
# global step:91593 episode :108/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05674
# global step:92351 episode :109/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05557
# global step:93110 episode :110/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05444
# global step:93865 episode :111/210 aver loss:0.00000 aver reward:-20.40000 explot:0.05333
# global step:94655 episode :112/210 aver loss:0.00000 aver reward:-20.50000 explot:0.05220
# global step:95412 episode :113/210 aver loss:0.00000 aver reward:-20.90000 explot:0.05115
# global step:96167 episode :114/210 aver loss:0.00000 aver reward:-21.00000 explot:0.05013
# global step:96925 episode :115/210 aver loss:0.00000 aver reward:-21.00000 explot:0.04913
# global step:97682 episode :116/210 aver loss:0.00000 aver reward:-21.00000 explot:0.04815
# global step:98438 episode :117/210 aver loss:0.00000 aver reward:-21.00000 explot:0.04720
# global step:99200 episode :118/210 aver loss:0.00000 aver reward:-21.00000 explot:0.04627
# global step:100075 episode :119/210 aver loss:0.00013 aver reward:-21.00000 explot:0.04523
# global step:100892 episode :120/210 aver loss:0.00157 aver reward:-21.00000 explot:0.04428
# global step:101708 episode :121/210 aver loss:0.00292 aver reward:-21.00000 explot:0.04336
# global step:102491 episode :122/210 aver loss:0.00394 aver reward:-21.00000 explot:0.04250
# global step:103276 episode :123/210 aver loss:0.00452 aver reward:-21.00000 explot:0.04166
# global step:104259 episode :124/210 aver loss:0.00490 aver reward:-21.00000 explot:0.04064
# global step:105093 episode :125/210 aver loss:0.00514 aver reward:-20.90000 explot:0.03980
# global step:105959 episode :126/210 aver loss:0.00533 aver reward:-20.90000 explot:0.03895
# global step:106858 episode :127/210 aver loss:0.00551 aver reward:-20.80000 explot:0.03810
# global step:107646 episode :128/210 aver loss:0.00568 aver reward:-20.80000 explot:0.03737
# global step:108429 episode :129/210 aver loss:0.00575 aver reward:-20.80000 explot:0.03667
# global step:109191 episode :130/210 aver loss:0.00447 aver reward:-20.80000 explot:0.03600
# global step:110129 episode :131/210 aver loss:0.00329 aver reward:-20.80000 explot:0.03520
# global step:110932 episode :132/210 aver loss:0.00241 aver reward:-20.80000 explot:0.03453
# global step:111764 episode :133/210 aver loss:0.00197 aver reward:-20.80000 explot:0.03386
# global step:112755 episode :134/210 aver loss:0.00173 aver reward:-20.70000 explot:0.03309
# global step:113540 episode :135/210 aver loss:0.00165 aver reward:-20.80000 explot:0.03249
# global step:114570 episode :136/210 aver loss:0.00160 aver reward:-20.60000 explot:0.03173
# global step:115553 episode :137/210 aver loss:0.00158 aver reward:-20.50000 explot:0.03103
# global step:116427 episode :138/210 aver loss:0.00156 aver reward:-20.50000 explot:0.03043
# global step:117275 episode :139/210 aver loss:0.00148 aver reward:-20.50000 explot:0.02986
# global step:118227 episode :140/210 aver loss:0.00148 aver reward:-20.40000 explot:0.02924
# global step:119246 episode :141/210 aver loss:0.00146 aver reward:-20.30000 explot:0.02859
# global step:120036 episode :142/210 aver loss:0.00146 aver reward:-20.30000 explot:0.02811
# global step:121004 episode :143/210 aver loss:0.00146 aver reward:-20.30000 explot:0.02754
# global step:122098 episode :144/210 aver loss:0.00148 aver reward:-20.30000 explot:0.02691
# global step:122988 episode :145/210 aver loss:0.00152 aver reward:-20.20000 explot:0.02641
# global step:123978 episode :146/210 aver loss:0.00158 aver reward:-20.40000 explot:0.02588
# global step:124755 episode :147/210 aver loss:0.00167 aver reward:-20.60000 explot:0.02547
# global step:125590 episode :148/210 aver loss:0.00174 aver reward:-20.50000 explot:0.02505
# global step:126480 episode :149/210 aver loss:0.00183 aver reward:-20.40000 explot:0.02461
# global step:127436 episode :150/210 aver loss:0.00189 aver reward:-20.40000 explot:0.02415
# global step:128538 episode :151/210 aver loss:0.00195 aver reward:-20.40000 explot:0.02364
# global step:129356 episode :152/210 aver loss:0.00201 aver reward:-20.40000 explot:0.02327
# global step:130167 episode :153/210 aver loss:0.00207 aver reward:-20.40000 explot:0.02292
# global step:130989 episode :154/210 aver loss:0.00209 aver reward:-20.50000 explot:0.02257
# global step:131908 episode :155/210 aver loss:0.00206 aver reward:-20.50000 explot:0.02219
# global step:132877 episode :156/210 aver loss:0.00201 aver reward:-20.40000 explot:0.02180
# global step:133928 episode :157/210 aver loss:0.00194 aver reward:-20.20000 explot:0.02140
# global step:134777 episode :158/210 aver loss:0.00187 aver reward:-20.30000 explot:0.02108
# global step:135891 episode :159/210 aver loss:0.00180 aver reward:-20.10000 explot:0.02068
# global step:136955 episode :160/210 aver loss:0.00174 aver reward:-20.00000 explot:0.02030
# global step:137930 episode :161/210 aver loss:0.00171 aver reward:-20.10000 explot:0.01997
# global step:139176 episode :162/210 aver loss:0.00166 aver reward:-19.80000 explot:0.01957
# global step:140317 episode :163/210 aver loss:0.00162 aver reward:-19.60000 explot:0.01921
# global step:141651 episode :164/210 aver loss:0.00158 aver reward:-19.40000 explot:0.01881
# global step:143099 episode :165/210 aver loss:0.00158 aver reward:-19.20000 explot:0.01840
# global step:144562 episode :166/210 aver loss:0.00157 aver reward:-19.10000 explot:0.01800
# global step:145844 episode :167/210 aver loss:0.00157 aver reward:-19.00000 explot:0.01766
# global step:147408 episode :168/210 aver loss:0.00157 aver reward:-18.50000 explot:0.01727
# global step:148722 episode :169/210 aver loss:0.00158 aver reward:-18.30000 explot:0.01696
# global step:150052 episode :170/210 aver loss:0.00159 aver reward:-18.20000 explot:0.01666
# global step:151485 episode :171/210 aver loss:0.00161 aver reward:-17.80000 explot:0.01635
# global step:152821 episode :172/210 aver loss:0.00162 aver reward:-17.60000 explot:0.01607
# global step:154257 episode :173/210 aver loss:0.00164 aver reward:-17.40000 explot:0.01579
# global step:155874 episode :174/210 aver loss:0.00169 aver reward:-17.10000 explot:0.01548
# global step:157460 episode :175/210 aver loss:0.00172 aver reward:-17.10000 explot:0.01520
# global step:158809 episode :176/210 aver loss:0.00177 aver reward:-17.30000 explot:0.01497
# global step:160458 episode :177/210 aver loss:0.00183 aver reward:-17.30000 explot:0.01471
# global step:161981 episode :178/210 aver loss:0.00186 aver reward:-17.60000 explot:0.01447
# global step:163624 episode :179/210 aver loss:0.00187 aver reward:-17.60000 explot:0.01424
# global step:165076 episode :180/210 aver loss:0.00188 aver reward:-17.50000 explot:0.01404
# global step:167163 episode :181/210 aver loss:0.00188 aver reward:-17.30000 explot:0.01376
# global step:168946 episode :182/210 aver loss:0.00193 aver reward:-17.10000 explot:0.01355
# global step:171128 episode :183/210 aver loss:0.00195 aver reward:-16.80000 explot:0.01330
# global step:173058 episode :184/210 aver loss:0.00193 aver reward:-16.50000 explot:0.01309
# global step:175309 episode :185/210 aver loss:0.00194 aver reward:-15.90000 explot:0.01287
# global step:177253 episode :186/210 aver loss:0.00191 aver reward:-15.20000 explot:0.01269
# global step:179357 episode :187/210 aver loss:0.00191 aver reward:-15.00000 explot:0.01251
# global step:181559 episode :188/210 aver loss:0.00193 aver reward:-14.40000 explot:0.01233
# global step:183941 episode :189/210 aver loss:0.00195 aver reward:-13.70000 explot:0.01215
# global step:185700 episode :190/210 aver loss:0.00196 aver reward:-13.70000 explot:0.01203
# global step:188822 episode :191/210 aver loss:0.00198 aver reward:-12.30000 explot:0.01183
# global step:192014 episode :192/210 aver loss:0.00199 aver reward:-10.50000 explot:0.01164
# global step:194525 episode :193/210 aver loss:0.00201 aver reward:-10.00000 explot:0.01151
# global step:197605 episode :194/210 aver loss:0.00205 aver reward:-8.60000 explot:0.01136
# global step:199840 episode :195/210 aver loss:0.00209 aver reward:-6.30000 explot:0.01127
# global step:201682 episode :196/210 aver loss:0.00218 aver reward:-3.00000 explot:0.01119
# global step:204700 episode :197/210 aver loss:0.00224 aver reward:-1.80000 explot:0.01108
# global step:207397 episode :198/210 aver loss:0.00228 aver reward:0.20000 explot:0.01098
# global step:209057 episode :199/210 aver loss:0.00233 aver reward:3.10000 explot:0.01093
# global step:211599 episode :200/210 aver loss:0.00241 aver reward:3.70000 explot:0.01086
# global step:214255 episode :201/210 aver loss:0.00250 aver reward:3.30000 explot:0.01078
# global step:217037 episode :202/210 aver loss:0.00260 aver reward:3.50000 explot:0.01071
# global step:219082 episode :203/210 aver loss:0.00270 aver reward:6.00000 explot:0.01067
# global step:221892 episode :204/210 aver loss:0.00278 aver reward:6.80000 explot:0.01061
# global step:224574 episode :205/210 aver loss:0.00285 aver reward:4.80000 explot:0.01056
# global step:227780 episode :206/210 aver loss:0.00288 aver reward:2.80000 explot:0.01050
# global step:229533 episode :207/210 aver loss:0.00291 aver reward:5.20000 explot:0.01047
# global step:231189 episode :208/210 aver loss:0.00296 aver reward:6.50000 explot:0.01045
# global step:233267 episode :209/210 aver loss:0.00303 aver reward:5.90000 explot:0.01042

# %%
# plot loss and rewards
import matplotlib.pyplot as plt
def plot_(losses, rewards):
    plt.figure()
    plt.title('rewards')
    plt.plot(list(range(len(rewards))), rewards)
    
    plt.figure()
    plt.title('loss')
    plt.plot(list(range(len(losses))),losses)
    plt.show()

plot_(losses, rewards)
